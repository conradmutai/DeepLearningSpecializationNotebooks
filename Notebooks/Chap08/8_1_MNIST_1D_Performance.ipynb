# %% [markdown]
# <a href="https://colab.research.google.com/github/conradmutai/DeepLearningSpecializationNotebooks/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-edhu8z1q
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-edhu8z1q
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.8.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 150   # Hidden dimensions
D_o = 10    # Output dimensions
# TODO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = torch.nn.Sequential(
    torch.nn.Linear(D_i, D_k),
    torch.nn.ReLU(),
    torch.nn.Linear(D_k, D_k),
    torch.nn.ReLU(),
    torch.nn.Linear(D_k, D_k),
    torch.nn.ReLU(),
    torch.nn.Linear(D_k, D_o)
);


def weights_init(layer_in):
  # TODO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  if isinstance(layer_in, torch.nn.Linear):
    torch.nn.init.kaiming_normal_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)


# Call the function you just defined
model.apply(weights_init)
# Out:
# Sequential(
#   (0): Linear(in_features=40, out_features=150, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=150, out_features=150, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=150, out_features=150, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=150, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.5)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Epoch     0, train loss 2.078501, train error 77.25,  test loss 2.099027, test error 77.80
# Epoch     1, train loss 1.882134, train error 71.03,  test loss 1.918176, test error 74.60
# Epoch     2, train loss 1.764698, train error 67.15,  test loss 1.820401, test error 73.20
# Epoch     3, train loss 1.688848, train error 64.93,  test loss 1.748135, test error 71.10
# Epoch     4, train loss 1.627892, train error 61.85,  test loss 1.708012, test error 69.40
# Epoch     5, train loss 1.575618, train error 59.72,  test loss 1.666054, test error 67.20
# Epoch     6, train loss 1.532903, train error 57.62,  test loss 1.639014, test error 67.00
# Epoch     7, train loss 1.493883, train error 54.88,  test loss 1.611780, test error 64.20
# Epoch     8, train loss 1.462460, train error 54.22,  test loss 1.594977, test error 63.40
# Epoch     9, train loss 1.426233, train error 51.83,  test loss 1.570023, test error 61.60
# Epoch    10, train loss 1.406169, train error 51.08,  test loss 1.552781, test error 60.80
# Epoch    11, train loss 1.387469, train error 49.45,  test loss 1.543752, test error 60.80
# Epoch    12, train loss 1.372114, train error 49.05,  test loss 1.531695, test error 59.90
# Epoch    13, train loss 1.356096, train error 48.22,  test loss 1.520520, test error 60.00
# Epoch    14, train loss 1.342232, train error 47.33,  test loss 1.512822, test error 58.90
# Epoch    15, train loss 1.328889, train error 46.17,  test loss 1.503341, test error 59.00
# Epoch    16, train loss 1.312802, train error 45.92,  test loss 1.495539, test error 57.80
# Epoch    17, train loss 1.300287, train error 45.85,  test loss 1.489359, test error 58.50
# Epoch    18, train loss 1.284655, train error 44.55,  test loss 1.480168, test error 58.30
# Epoch    19, train loss 1.270083, train error 43.92,  test loss 1.470323, test error 57.90
# Epoch    20, train loss 1.262291, train error 43.35,  test loss 1.464620, test error 57.50
# Epoch    21, train loss 1.254561, train error 43.08,  test loss 1.458553, test error 56.80
# Epoch    22, train loss 1.247914, train error 42.62,  test loss 1.453073, test error 56.60
# Epoch    23, train loss 1.241419, train error 42.00,  test loss 1.450830, test error 56.40
# Epoch    24, train loss 1.236396, train error 42.55,  test loss 1.445437, test error 56.60
# Epoch    25, train loss 1.228770, train error 42.08,  test loss 1.444071, test error 56.40
# Epoch    26, train loss 1.221978, train error 41.70,  test loss 1.437996, test error 56.00
# Epoch    27, train loss 1.215635, train error 41.38,  test loss 1.432832, test error 56.10
# Epoch    28, train loss 1.209184, train error 41.28,  test loss 1.429976, test error 54.80
# Epoch    29, train loss 1.202520, train error 40.70,  test loss 1.425037, test error 56.20
# Epoch    30, train loss 1.198780, train error 40.42,  test loss 1.422623, test error 55.30
# Epoch    31, train loss 1.195663, train error 40.25,  test loss 1.421146, test error 55.50
# Epoch    32, train loss 1.192781, train error 40.42,  test loss 1.420704, test error 55.20
# Epoch    33, train loss 1.189435, train error 40.03,  test loss 1.417644, test error 55.50
# Epoch    34, train loss 1.186403, train error 40.08,  test loss 1.414944, test error 55.10
# Epoch    35, train loss 1.183230, train error 39.90,  test loss 1.414718, test error 54.80
# Epoch    36, train loss 1.180186, train error 39.90,  test loss 1.410843, test error 55.00
# Epoch    37, train loss 1.177362, train error 39.53,  test loss 1.409469, test error 54.50
# Epoch    38, train loss 1.174008, train error 39.33,  test loss 1.408519, test error 54.80
# Epoch    39, train loss 1.171225, train error 39.08,  test loss 1.407609, test error 55.10
# Epoch    40, train loss 1.169518, train error 39.05,  test loss 1.405608, test error 54.80
# Epoch    41, train loss 1.167901, train error 38.92,  test loss 1.404373, test error 54.50
# Epoch    42, train loss 1.166391, train error 38.80,  test loss 1.403848, test error 54.70
# Epoch    43, train loss 1.164863, train error 38.75,  test loss 1.402847, test error 54.60
# Epoch    44, train loss 1.163406, train error 38.85,  test loss 1.401451, test error 54.80
# Epoch    45, train loss 1.161916, train error 38.65,  test loss 1.400868, test error 54.30
# Epoch    46, train loss 1.160391, train error 38.58,  test loss 1.400441, test error 54.40
# Epoch    47, train loss 1.158929, train error 38.47,  test loss 1.399248, test error 54.30
# Epoch    48, train loss 1.157412, train error 38.47,  test loss 1.398359, test error 54.50
# Epoch    49, train loss 1.155921, train error 38.50,  test loss 1.397510, test error 54.50

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TODO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?
