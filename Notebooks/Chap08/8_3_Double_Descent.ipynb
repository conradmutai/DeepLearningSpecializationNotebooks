# %% [markdown]
# <a href="https://colab.research.google.com/github/conradmutai/DeepLearningSpecializationNotebooks/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-12r84_7t
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-12r84_7t
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.8.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=1daf6c0e1323a7e8f110441f88531cb633d752558b6b5a3c141f5abcde9740ea
#   Stored in directory: /tmp/pip-ephem-wheel-cache-4xo15b47/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
    nn.Linear(D_i, D_k),
    nn.ReLU(),
    nn.Linear(D_k, D_k),
    nn.ReLU(),
    nn.Linear(D_k, D_o)
  )

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test = torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.294884, train error 89.22,  test loss 2.296779, test error 89.47
# Epoch   100, train loss 1.877338, train error 71.22,  test loss 1.739978, test error 69.07
# Epoch   200, train loss 1.864125, train error 70.55,  test loss 1.703819, test error 68.22
# Epoch   300, train loss 1.850104, train error 70.12,  test loss 1.697392, test error 67.65
# Epoch   400, train loss 1.850804, train error 69.88,  test loss 1.700752, test error 67.57
# Epoch   500, train loss 1.853589, train error 70.28,  test loss 1.704958, test error 68.18
# Epoch   600, train loss 1.844371, train error 70.75,  test loss 1.694303, test error 67.00
# Epoch   700, train loss 1.847551, train error 70.05,  test loss 1.689714, test error 66.95
# Epoch   800, train loss 1.830070, train error 69.20,  test loss 1.668627, test error 66.38
# Epoch   900, train loss 1.827153, train error 68.90,  test loss 1.669281, test error 65.90
# Training model with   4 hidden variables
# Epoch     0, train loss 2.248313, train error 82.50,  test loss 2.227741, test error 81.12
# Epoch   100, train loss 1.787070, train error 65.50,  test loss 1.621376, test error 62.58
# Epoch   200, train loss 1.721759, train error 62.22,  test loss 1.517482, test error 58.08
# Epoch   300, train loss 1.715408, train error 61.97,  test loss 1.505060, test error 58.35
# Epoch   400, train loss 1.710625, train error 61.85,  test loss 1.501823, test error 58.20
# Epoch   500, train loss 1.708928, train error 62.30,  test loss 1.505372, test error 58.45
# Epoch   600, train loss 1.711179, train error 62.12,  test loss 1.497937, test error 57.58
# Epoch   700, train loss 1.707186, train error 61.83,  test loss 1.502889, test error 58.15
# Epoch   800, train loss 1.707795, train error 62.28,  test loss 1.497499, test error 57.75
# Epoch   900, train loss 1.707856, train error 61.78,  test loss 1.501741, test error 57.92
# Training model with   6 hidden variables
# Epoch     0, train loss 2.217386, train error 85.53,  test loss 2.212359, test error 86.93
# Epoch   100, train loss 1.692813, train error 59.72,  test loss 1.551688, test error 57.67
# Epoch   200, train loss 1.642111, train error 56.95,  test loss 1.480528, test error 55.67
# Epoch   300, train loss 1.622211, train error 56.38,  test loss 1.478860, test error 55.85
# Epoch   400, train loss 1.612428, train error 56.12,  test loss 1.464509, test error 55.55
# Epoch   500, train loss 1.616316, train error 56.60,  test loss 1.471974, test error 55.28
# Epoch   600, train loss 1.606877, train error 56.08,  test loss 1.475638, test error 55.88
# Epoch   700, train loss 1.609887, train error 56.00,  test loss 1.478258, test error 55.90
# Epoch   800, train loss 1.610306, train error 56.08,  test loss 1.485988, test error 56.10
# Epoch   900, train loss 1.608745, train error 56.12,  test loss 1.482881, test error 56.38
# Training model with   8 hidden variables
# Epoch     0, train loss 2.238594, train error 84.05,  test loss 2.234458, test error 83.75
# Epoch   100, train loss 1.576971, train error 56.67,  test loss 1.419132, test error 54.05
# Epoch   200, train loss 1.481125, train error 50.22,  test loss 1.301062, test error 48.12
# Epoch   300, train loss 1.459873, train error 49.60,  test loss 1.284226, test error 47.60
# Epoch   400, train loss 1.452826, train error 49.17,  test loss 1.271380, test error 47.28
# Epoch   500, train loss 1.446903, train error 49.25,  test loss 1.280541, test error 47.35
# Epoch   600, train loss 1.443233, train error 48.33,  test loss 1.276027, test error 48.15
# Epoch   700, train loss 1.442863, train error 49.33,  test loss 1.277262, test error 47.50
# Epoch   800, train loss 1.442662, train error 48.28,  test loss 1.291011, test error 48.50
# Epoch   900, train loss 1.438215, train error 48.47,  test loss 1.286848, test error 47.62
# Training model with  10 hidden variables
# Epoch     0, train loss 2.260146, train error 83.75,  test loss 2.265909, test error 84.00
# Epoch   100, train loss 1.590378, train error 56.12,  test loss 1.457901, test error 55.95
# Epoch   200, train loss 1.526685, train error 53.03,  test loss 1.397613, test error 52.72
# Epoch   300, train loss 1.460360, train error 50.08,  test loss 1.334291, test error 50.22
# Epoch   400, train loss 1.437814, train error 49.03,  test loss 1.317765, test error 48.97
# Epoch   500, train loss 1.414809, train error 48.25,  test loss 1.292276, test error 48.05
# Epoch   600, train loss 1.401764, train error 47.72,  test loss 1.312043, test error 48.42
# Epoch   700, train loss 1.396928, train error 47.22,  test loss 1.321942, test error 48.85
# Epoch   800, train loss 1.393941, train error 47.12,  test loss 1.314708, test error 48.88
# Epoch   900, train loss 1.390169, train error 47.00,  test loss 1.319386, test error 48.47
# Training model with  14 hidden variables
# Epoch     0, train loss 2.249627, train error 84.05,  test loss 2.250437, test error 84.12
# Epoch   100, train loss 1.453643, train error 50.33,  test loss 1.369698, test error 52.50
# Epoch   200, train loss 1.364514, train error 46.35,  test loss 1.338571, test error 49.90
# Epoch   300, train loss 1.336214, train error 44.17,  test loss 1.345964, test error 50.62
# Epoch   400, train loss 1.318573, train error 44.30,  test loss 1.347804, test error 50.40
# Epoch   500, train loss 1.302668, train error 44.38,  test loss 1.348252, test error 49.50
# Epoch   600, train loss 1.290120, train error 42.90,  test loss 1.355295, test error 49.90
# Epoch   700, train loss 1.283880, train error 43.28,  test loss 1.364512, test error 49.80
# Epoch   800, train loss 1.282819, train error 43.88,  test loss 1.365169, test error 49.45
# Epoch   900, train loss 1.279667, train error 43.28,  test loss 1.372797, test error 50.40
# Training model with  18 hidden variables
# Epoch     0, train loss 2.163362, train error 79.88,  test loss 2.146289, test error 79.57
# Epoch   100, train loss 1.287842, train error 43.65,  test loss 1.276336, test error 47.53
# Epoch   200, train loss 1.218683, train error 42.38,  test loss 1.344034, test error 48.62
# Epoch   300, train loss 1.172147, train error 40.00,  test loss 1.379156, test error 48.05
# Epoch   400, train loss 1.148314, train error 39.80,  test loss 1.403434, test error 48.45
# Epoch   500, train loss 1.138851, train error 38.97,  test loss 1.435048, test error 48.80
# Epoch   600, train loss 1.121264, train error 38.38,  test loss 1.473833, test error 48.88
# Epoch   700, train loss 1.118601, train error 38.83,  test loss 1.500955, test error 49.62
# Epoch   800, train loss 1.115772, train error 38.97,  test loss 1.536929, test error 49.22
# Epoch   900, train loss 1.110380, train error 38.88,  test loss 1.552859, test error 49.28
# Training model with  22 hidden variables
# Epoch     0, train loss 2.112870, train error 79.72,  test loss 2.052160, test error 77.60
# Epoch   100, train loss 1.289932, train error 43.17,  test loss 1.331343, test error 49.47
# Epoch   200, train loss 1.170989, train error 40.22,  test loss 1.388464, test error 50.15
# Epoch   300, train loss 1.100784, train error 37.97,  test loss 1.441807, test error 50.03
# Epoch   400, train loss 1.057578, train error 36.70,  test loss 1.485388, test error 50.65
# Epoch   500, train loss 1.030268, train error 35.60,  test loss 1.560785, test error 52.22
# Epoch   600, train loss 1.031299, train error 37.00,  test loss 1.623398, test error 52.65
# Epoch   700, train loss 1.024324, train error 36.40,  test loss 1.684834, test error 53.10
# Epoch   800, train loss 1.004767, train error 34.72,  test loss 1.677046, test error 52.00
# Epoch   900, train loss 1.000213, train error 34.10,  test loss 1.680190, test error 52.30
# Training model with  26 hidden variables
# Epoch     0, train loss 2.138997, train error 79.43,  test loss 2.118068, test error 79.32
# Epoch   100, train loss 1.176879, train error 39.20,  test loss 1.281720, test error 46.65
# Epoch   200, train loss 1.022149, train error 34.00,  test loss 1.402372, test error 48.85
# Epoch   300, train loss 0.942299, train error 31.18,  test loss 1.509681, test error 49.50
# Epoch   400, train loss 0.900929, train error 30.70,  test loss 1.630726, test error 51.33
# Epoch   500, train loss 0.884082, train error 31.25,  test loss 1.752987, test error 52.70
# Epoch   600, train loss 0.855358, train error 29.18,  test loss 1.813469, test error 52.22
# Epoch   700, train loss 0.824563, train error 28.18,  test loss 1.874718, test error 52.05
# Epoch   800, train loss 0.825690, train error 28.82,  test loss 1.907663, test error 52.55
# Epoch   900, train loss 0.807546, train error 27.50,  test loss 1.971339, test error 53.42
# Training model with  30 hidden variables
# Epoch     0, train loss 2.168642, train error 79.15,  test loss 2.128495, test error 78.10
# Epoch   100, train loss 1.070777, train error 35.65,  test loss 1.320048, test error 48.25
# Epoch   200, train loss 0.899005, train error 29.28,  test loss 1.477437, test error 49.67
# Epoch   300, train loss 0.820033, train error 26.78,  test loss 1.633302, test error 50.97
# Epoch   400, train loss 0.770603, train error 25.18,  test loss 1.765729, test error 51.17
# Epoch   500, train loss 0.739874, train error 24.78,  test loss 1.955910, test error 53.12
# Epoch   600, train loss 0.711805, train error 23.57,  test loss 2.037376, test error 52.90
# Epoch   700, train loss 0.703989, train error 22.82,  test loss 2.141301, test error 53.15
# Epoch   800, train loss 0.679283, train error 22.12,  test loss 2.266272, test error 54.45
# Epoch   900, train loss 0.654629, train error 21.57,  test loss 2.368545, test error 53.55
# Training model with  35 hidden variables
# Epoch     0, train loss 2.098342, train error 77.40,  test loss 2.056442, test error 77.18
# Epoch   100, train loss 1.039376, train error 34.72,  test loss 1.367454, test error 49.53
# Epoch   200, train loss 0.813369, train error 26.05,  test loss 1.588894, test error 49.35
# Epoch   300, train loss 0.712767, train error 23.38,  test loss 1.919868, test error 51.15
# Epoch   400, train loss 0.610637, train error 20.18,  test loss 2.254558, test error 52.67
# Epoch   500, train loss 0.578572, train error 19.72,  test loss 2.598622, test error 54.47
# Epoch   600, train loss 0.543118, train error 18.35,  test loss 2.868723, test error 54.53
# Epoch   700, train loss 0.510026, train error 16.57,  test loss 3.139540, test error 54.17
# Epoch   800, train loss 0.503435, train error 16.57,  test loss 3.336000, test error 55.70
# Epoch   900, train loss 0.462132, train error 15.62,  test loss 3.563503, test error 54.72
# Training model with  40 hidden variables
# Epoch     0, train loss 2.085577, train error 78.28,  test loss 2.043338, test error 77.60
# Epoch   100, train loss 0.906389, train error 29.38,  test loss 1.470204, test error 50.55
# Epoch   200, train loss 0.664584, train error 21.75,  test loss 1.914955, test error 52.25
# Epoch   300, train loss 0.532761, train error 17.18,  test loss 2.514450, test error 54.40
# Epoch   400, train loss 0.434090, train error 14.60,  test loss 3.160960, test error 55.45
# Epoch   500, train loss 0.367612, train error 12.53,  test loss 3.808377, test error 56.67
# Epoch   600, train loss 0.346663, train error 12.05,  test loss 4.435485, test error 56.65
# Epoch   700, train loss 0.292226, train error 10.22,  test loss 5.103207, test error 58.08
# Epoch   800, train loss 0.298729, train error 10.45,  test loss 5.886596, test error 58.47
# Epoch   900, train loss 0.279335, train error 10.07,  test loss 6.398043, test error 57.60
# Training model with  45 hidden variables
# Epoch     0, train loss 2.073790, train error 76.55,  test loss 2.035904, test error 75.97
# Epoch   100, train loss 0.816742, train error 26.10,  test loss 1.483388, test error 49.88
# Epoch   200, train loss 0.489364, train error 15.75,  test loss 2.244449, test error 53.72
# Epoch   300, train loss 0.348234, train error 11.62,  test loss 3.361969, test error 55.85
# Epoch   400, train loss 0.215726, train error 6.82,  test loss 4.543466, test error 55.85
# Epoch   500, train loss 0.167932, train error 5.75,  test loss 5.751970, test error 56.12
# Epoch   600, train loss 0.176145, train error 6.07,  test loss 6.768539, test error 56.10
# Epoch   700, train loss 0.013672, train error 0.00,  test loss 7.909223, test error 56.17
# Epoch   800, train loss 0.008237, train error 0.00,  test loss 8.613307, test error 56.25
# Epoch   900, train loss 0.006091, train error 0.00,  test loss 9.121409, test error 56.40
# Training model with  50 hidden variables
# Epoch     0, train loss 2.114076, train error 77.07,  test loss 2.096662, test error 77.88
# Epoch   100, train loss 0.702101, train error 22.00,  test loss 1.595665, test error 50.60
# Epoch   200, train loss 0.336861, train error 9.80,  test loss 2.747653, test error 53.67
# Epoch   300, train loss 0.142452, train error 2.85,  test loss 4.282023, test error 56.45
# Epoch   400, train loss 0.036081, train error 0.10,  test loss 5.744674, test error 55.58
# Epoch   500, train loss 0.015092, train error 0.00,  test loss 6.767936, test error 55.95
# Epoch   600, train loss 0.009431, train error 0.00,  test loss 7.435968, test error 56.00
# Epoch   700, train loss 0.006763, train error 0.00,  test loss 7.922153, test error 55.97
# Epoch   800, train loss 0.005137, train error 0.00,  test loss 8.329268, test error 56.10
# Epoch   900, train loss 0.004125, train error 0.00,  test loss 8.650344, test error 56.22
# Training model with  55 hidden variables
# Epoch     0, train loss 2.098875, train error 77.55,  test loss 2.053521, test error 76.80
# Epoch   100, train loss 0.596895, train error 18.20,  test loss 1.709638, test error 52.20
# Epoch   200, train loss 0.196656, train error 4.22,  test loss 3.258701, test error 55.50
# Epoch   300, train loss 0.032339, train error 0.00,  test loss 5.019403, test error 56.33
# Epoch   400, train loss 0.012627, train error 0.00,  test loss 6.023545, test error 56.38
# Epoch   500, train loss 0.007636, train error 0.00,  test loss 6.638193, test error 56.35
# Epoch   600, train loss 0.005274, train error 0.00,  test loss 7.079212, test error 56.33
# Epoch   700, train loss 0.004003, train error 0.00,  test loss 7.414917, test error 56.35
# Epoch   800, train loss 0.003182, train error 0.00,  test loss 7.703221, test error 56.30
# Epoch   900, train loss 0.002625, train error 0.00,  test loss 7.948769, test error 56.33
# Training model with  60 hidden variables
# Epoch     0, train loss 2.062595, train error 76.43,  test loss 2.026441, test error 76.70
# Epoch   100, train loss 0.534048, train error 15.90,  test loss 1.804970, test error 52.38
# Epoch   200, train loss 0.113887, train error 1.57,  test loss 3.463125, test error 55.10
# Epoch   300, train loss 0.019128, train error 0.00,  test loss 4.883649, test error 54.88
# Epoch   400, train loss 0.009178, train error 0.00,  test loss 5.602662, test error 55.47
# Epoch   500, train loss 0.005839, train error 0.00,  test loss 6.063779, test error 55.47
# Epoch   600, train loss 0.004204, train error 0.00,  test loss 6.406620, test error 55.38
# Epoch   700, train loss 0.003230, train error 0.00,  test loss 6.683557, test error 55.50
# Epoch   800, train loss 0.002593, train error 0.00,  test loss 6.910048, test error 55.53
# Epoch   900, train loss 0.002155, train error 0.00,  test loss 7.104708, test error 55.67
# Training model with  70 hidden variables
# Epoch     0, train loss 2.024335, train error 75.78,  test loss 1.967052, test error 75.85
# Epoch   100, train loss 0.365339, train error 8.72,  test loss 1.981919, test error 52.92
# Epoch   200, train loss 0.032376, train error 0.00,  test loss 3.653092, test error 53.97
# Epoch   300, train loss 0.010617, train error 0.00,  test loss 4.414697, test error 54.12
# Epoch   400, train loss 0.005973, train error 0.00,  test loss 4.847131, test error 53.92
# Epoch   500, train loss 0.004051, train error 0.00,  test loss 5.157210, test error 54.20
# Epoch   600, train loss 0.002991, train error 0.00,  test loss 5.386447, test error 54.00
# Epoch   700, train loss 0.002350, train error 0.00,  test loss 5.577610, test error 54.08
# Epoch   800, train loss 0.001923, train error 0.00,  test loss 5.736912, test error 54.08
# Epoch   900, train loss 0.001617, train error 0.00,  test loss 5.871327, test error 54.20
# Training model with  80 hidden variables
# Epoch     0, train loss 2.020001, train error 76.18,  test loss 1.975262, test error 77.18
# Epoch   100, train loss 0.230762, train error 3.43,  test loss 2.071866, test error 51.55
# Epoch   200, train loss 0.021077, train error 0.00,  test loss 3.412657, test error 52.08
# Epoch   300, train loss 0.008466, train error 0.00,  test loss 3.971555, test error 51.85
# Epoch   400, train loss 0.004958, train error 0.00,  test loss 4.304832, test error 51.92
# Epoch   500, train loss 0.003418, train error 0.00,  test loss 4.539149, test error 51.88
# Epoch   600, train loss 0.002564, train error 0.00,  test loss 4.722159, test error 51.85
# Epoch   700, train loss 0.002030, train error 0.00,  test loss 4.873777, test error 51.88
# Epoch   800, train loss 0.001669, train error 0.00,  test loss 4.997785, test error 51.65
# Epoch   900, train loss 0.001409, train error 0.00,  test loss 5.106036, test error 51.62
# Training model with  90 hidden variables
# Epoch     0, train loss 2.008521, train error 74.93,  test loss 1.942101, test error 74.18
# Epoch   100, train loss 0.160549, train error 1.62,  test loss 2.160585, test error 51.50
# Epoch   200, train loss 0.015828, train error 0.00,  test loss 3.324025, test error 53.05
# Epoch   300, train loss 0.006823, train error 0.00,  test loss 3.784018, test error 53.25
# Epoch   400, train loss 0.004131, train error 0.00,  test loss 4.069866, test error 53.47
# Epoch   500, train loss 0.002894, train error 0.00,  test loss 4.268605, test error 53.45
# Epoch   600, train loss 0.002198, train error 0.00,  test loss 4.426316, test error 53.40
# Epoch   700, train loss 0.001755, train error 0.00,  test loss 4.556809, test error 53.45
# Epoch   800, train loss 0.001452, train error 0.00,  test loss 4.665473, test error 53.47
# Epoch   900, train loss 0.001232, train error 0.00,  test loss 4.759393, test error 53.45
# Training model with 100 hidden variables
# Epoch     0, train loss 1.988608, train error 74.00,  test loss 1.907205, test error 74.03
# Epoch   100, train loss 0.081548, train error 0.12,  test loss 2.124776, test error 49.12
# Epoch   200, train loss 0.011931, train error 0.00,  test loss 2.902842, test error 48.80
# Epoch   300, train loss 0.005583, train error 0.00,  test loss 3.231426, test error 49.20
# Epoch   400, train loss 0.003481, train error 0.00,  test loss 3.441206, test error 49.10
# Epoch   500, train loss 0.002481, train error 0.00,  test loss 3.592242, test error 49.17
# Epoch   600, train loss 0.001901, train error 0.00,  test loss 3.712237, test error 49.17
# Epoch   700, train loss 0.001527, train error 0.00,  test loss 3.807695, test error 49.35
# Epoch   800, train loss 0.001270, train error 0.00,  test loss 3.890586, test error 49.38
# Epoch   900, train loss 0.001081, train error 0.00,  test loss 3.961587, test error 49.33
# Training model with 120 hidden variables
# Epoch     0, train loss 1.974708, train error 72.72,  test loss 1.910824, test error 73.38
# Epoch   100, train loss 0.048274, train error 0.00,  test loss 2.291007, test error 51.17
# Epoch   200, train loss 0.009224, train error 0.00,  test loss 2.930533, test error 50.65
# Epoch   300, train loss 0.004614, train error 0.00,  test loss 3.221308, test error 50.72
# Epoch   400, train loss 0.002955, train error 0.00,  test loss 3.405011, test error 50.83
# Epoch   500, train loss 0.002134, train error 0.00,  test loss 3.543130, test error 50.83
# Epoch   600, train loss 0.001649, train error 0.00,  test loss 3.652783, test error 50.83
# Epoch   700, train loss 0.001334, train error 0.00,  test loss 3.742484, test error 50.83
# Epoch   800, train loss 0.001114, train error 0.00,  test loss 3.819787, test error 50.85
# Epoch   900, train loss 0.000953, train error 0.00,  test loss 3.887147, test error 50.88
# Training model with 140 hidden variables
# Epoch     0, train loss 1.969579, train error 71.93,  test loss 1.897939, test error 72.15
# Epoch   100, train loss 0.036042, train error 0.00,  test loss 2.156089, test error 49.22
# Epoch   200, train loss 0.008211, train error 0.00,  test loss 2.632629, test error 49.28
# Epoch   300, train loss 0.004206, train error 0.00,  test loss 2.859535, test error 49.15
# Epoch   400, train loss 0.002733, train error 0.00,  test loss 3.008173, test error 49.10
# Epoch   500, train loss 0.001987, train error 0.00,  test loss 3.118954, test error 49.08
# Epoch   600, train loss 0.001544, train error 0.00,  test loss 3.205914, test error 49.00
# Epoch   700, train loss 0.001254, train error 0.00,  test loss 3.278641, test error 48.72
# Epoch   800, train loss 0.001050, train error 0.00,  test loss 3.340991, test error 48.70
# Epoch   900, train loss 0.000899, train error 0.00,  test loss 3.394537, test error 48.62
# Training model with 160 hidden variables
# Epoch     0, train loss 1.939276, train error 71.00,  test loss 1.856724, test error 72.80
# Epoch   100, train loss 0.027851, train error 0.00,  test loss 2.137677, test error 49.60
# Epoch   200, train loss 0.006999, train error 0.00,  test loss 2.546705, test error 49.67
# Epoch   300, train loss 0.003694, train error 0.00,  test loss 2.748421, test error 49.58
# Epoch   400, train loss 0.002431, train error 0.00,  test loss 2.882977, test error 49.58
# Epoch   500, train loss 0.001781, train error 0.00,  test loss 2.984703, test error 49.70
# Epoch   600, train loss 0.001392, train error 0.00,  test loss 3.065830, test error 49.72
# Epoch   700, train loss 0.001134, train error 0.00,  test loss 3.133018, test error 49.75
# Epoch   800, train loss 0.000952, train error 0.00,  test loss 3.191282, test error 49.72
# Epoch   900, train loss 0.000817, train error 0.00,  test loss 3.241483, test error 49.90
# Training model with 180 hidden variables
# Epoch     0, train loss 1.940419, train error 71.90,  test loss 1.859603, test error 71.90
# Epoch   100, train loss 0.024311, train error 0.00,  test loss 1.982069, test error 48.47
# Epoch   200, train loss 0.006558, train error 0.00,  test loss 2.313323, test error 47.97
# Epoch   300, train loss 0.003505, train error 0.00,  test loss 2.479258, test error 48.12
# Epoch   400, train loss 0.002322, train error 0.00,  test loss 2.591571, test error 48.22
# Epoch   500, train loss 0.001707, train error 0.00,  test loss 2.676489, test error 48.28
# Epoch   600, train loss 0.001336, train error 0.00,  test loss 2.743677, test error 48.20
# Epoch   700, train loss 0.001091, train error 0.00,  test loss 2.800215, test error 48.10
# Epoch   800, train loss 0.000917, train error 0.00,  test loss 2.848444, test error 48.20
# Epoch   900, train loss 0.000788, train error 0.00,  test loss 2.891034, test error 48.28
# Training model with 200 hidden variables
# Epoch     0, train loss 1.920920, train error 70.70,  test loss 1.850548, test error 71.75
# Epoch   100, train loss 0.020796, train error 0.00,  test loss 2.026064, test error 48.33
# Epoch   200, train loss 0.006020, train error 0.00,  test loss 2.339536, test error 48.05
# Epoch   300, train loss 0.003279, train error 0.00,  test loss 2.500757, test error 48.17
# Epoch   400, train loss 0.002189, train error 0.00,  test loss 2.607893, test error 48.22
# Epoch   500, train loss 0.001618, train error 0.00,  test loss 2.690618, test error 48.20
# Epoch   600, train loss 0.001272, train error 0.00,  test loss 2.756767, test error 48.25
# Epoch   700, train loss 0.001041, train error 0.00,  test loss 2.811790, test error 48.20
# Epoch   800, train loss 0.000877, train error 0.00,  test loss 2.859436, test error 48.12
# Epoch   900, train loss 0.000755, train error 0.00,  test loss 2.901214, test error 48.03
# Training model with 250 hidden variables
# Epoch     0, train loss 1.885105, train error 68.65,  test loss 1.805723, test error 70.28
# Epoch   100, train loss 0.016726, train error 0.00,  test loss 1.941734, test error 47.88
# Epoch   200, train loss 0.005282, train error 0.00,  test loss 2.199859, test error 47.97
# Epoch   300, train loss 0.002940, train error 0.00,  test loss 2.338510, test error 47.85
# Epoch   400, train loss 0.001987, train error 0.00,  test loss 2.433558, test error 47.88
# Epoch   500, train loss 0.001479, train error 0.00,  test loss 2.505330, test error 47.88
# Epoch   600, train loss 0.001168, train error 0.00,  test loss 2.562256, test error 47.90
# Epoch   700, train loss 0.000959, train error 0.00,  test loss 2.611168, test error 47.95
# Epoch   800, train loss 0.000810, train error 0.00,  test loss 2.652969, test error 47.83
# Epoch   900, train loss 0.000699, train error 0.00,  test loss 2.689116, test error 47.78
# Training model with 300 hidden variables
# Epoch     0, train loss 1.903328, train error 70.47,  test loss 1.838732, test error 71.40
# Epoch   100, train loss 0.014525, train error 0.00,  test loss 1.892849, test error 46.88
# Epoch   200, train loss 0.004818, train error 0.00,  test loss 2.117544, test error 46.85
# Epoch   300, train loss 0.002721, train error 0.00,  test loss 2.239679, test error 46.80
# Epoch   400, train loss 0.001851, train error 0.00,  test loss 2.322359, test error 46.92
# Epoch   500, train loss 0.001384, train error 0.00,  test loss 2.385826, test error 47.12
# Epoch   600, train loss 0.001096, train error 0.00,  test loss 2.437533, test error 47.03
# Epoch   700, train loss 0.000902, train error 0.00,  test loss 2.480169, test error 46.95
# Epoch   800, train loss 0.000764, train error 0.00,  test loss 2.517236, test error 46.97
# Epoch   900, train loss 0.000660, train error 0.00,  test loss 2.549843, test error 46.95
# Training model with 400 hidden variables
# Epoch     0, train loss 1.823462, train error 65.40,  test loss 1.765702, test error 68.50
# Epoch   100, train loss 0.011598, train error 0.00,  test loss 1.758453, test error 45.35
# Epoch   200, train loss 0.004146, train error 0.00,  test loss 1.940599, test error 45.08
# Epoch   300, train loss 0.002402, train error 0.00,  test loss 2.039241, test error 45.33
# Epoch   400, train loss 0.001654, train error 0.00,  test loss 2.107302, test error 45.20
# Epoch   500, train loss 0.001247, train error 0.00,  test loss 2.160516, test error 45.20
# Epoch   600, train loss 0.000993, train error 0.00,  test loss 2.202633, test error 45.20
# Epoch   700, train loss 0.000821, train error 0.00,  test loss 2.238654, test error 45.22
# Epoch   800, train loss 0.000697, train error 0.00,  test loss 2.269974, test error 45.30
# Epoch   900, train loss 0.000603, train error 0.00,  test loss 2.297355, test error 45.22

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
