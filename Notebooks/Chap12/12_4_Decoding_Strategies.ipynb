# %% [markdown]
# <a href="https://colab.research.google.com/github/conradmutai/DeepLearningSpecializationNotebooks/blob/main/Notebooks/Chap12/12_4_Decoding_Strategies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 12.4: Decoding strategies**
#
# This practical investigates neural decoding from transformer models.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (5.12.1)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (1.20.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from transformers) (0.25.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.8.0)
# Requirement already satisfied: tqdm>=4.60 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.3)
# Requirement already satisfied: click>=8.4.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (3.29.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.14.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers) (0.1.2)

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer, set_seed
import torch
import torch.nn.functional as F
import numpy as np

# %%
# Load model and tokenizer
model = GPT2LMHeadModel.from_pretrained('gpt2')
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %% [markdown]
# # Decoding from GPT2
#
# This tutorial investigates how to use GPT2 (the forerunner of GPT3) to generate text.  There are a number of ways to do this that trade-off the realism of the text against the amount of variation.
#
# At every stage, GPT2 takes an input string and returns a probability for each of the possible subsequent tokens.  We can choose what to do with these probability.  We could always *greedily choose* the most likely next token, or we could draw a *sample* randomly according to the probabilities.  There are also intermediate strategies such as *top-k sampling* and *nucleus sampling*, that have some controlled randomness.
#
# We'll also investigate *beam search* -- the idea is that rather than greedily take the next best token at each stage, we maintain a set of hypotheses  (beams)as we add each subsequent token and return the most likely overall hypothesis.  This is not necessarily the same result we get from greedily choosing the next token.

# %% [markdown]
# First, let's investigate the token themselves.  The code below prints out the vocabulary size and shows 20 random tokens.

# %%
np.random.seed(1)
print("Number of tokens in dictionary = %d"%(tokenizer.vocab_size))
for i in range(20):
  index = np.random.randint(tokenizer.vocab_size)
  print("Token: %d "%(index)+tokenizer.decode(torch.tensor(index), skip_special_tokens=True))
# Out:
# Number of tokens in dictionary = 50257
# Token: 33003  Mormons
# Token: 12172  cam
# Token: 5192  trig
# Token: 32511 ojure
# Token: 50057  gist
# Token: 43723  Petition
# Token: 7813  sin
# Token: 21440  Witness
# Token: 32912  Remy
# Token: 20609 isure
# Token: 49100  creeps
# Token: 7751  fasc
# Token: 43757  Alc
# Token: 31228  messenger
# Token: 36230  SYSTEM
# Token: 32025  precipitation
# Token: 21758  cores
# Token: 45413  Forestry
# Token: 35730  guru
# Token: 8444  Disc

# %% [markdown]
# # Sampling
#
# Each time we run GPT2 it will take in a set of tokens, and return a probability over each of the possible next tokens.  The simplest thing we could do is to just draw a sample from this probability distribution each time.

# %%
def sample_next_token(input_tokens, model, tokenizer):
  # Run model to get prediction over next output
  outputs = model(input_ids = input_tokens['input_ids'], attention_mask = input_tokens['attention_mask'])
  # Find prediction
  prob_over_tokens = F.softmax(outputs.logits, dim=-1).detach().numpy()[0,-1]
  # TODO Draw a random token according to the probabilities
  # next_token should be an array with an sole integer in it (as below)
  # Use:  https://numpy.org/doc/stable/reference/random/generated/numpy.random.choice.html
  # Replace this line
  next_token = np.random.choice(len(prob_over_tokens), size=1, p=prob_over_tokens)


  # Append token to sentence
  output_tokens = input_tokens
  output_tokens["input_ids"] = torch.cat((output_tokens['input_ids'],torch.tensor([next_token])),dim=1)
  output_tokens['attention_mask'] = torch.cat((output_tokens['attention_mask'],torch.tensor([[1]])),dim=1)
  output_tokens['last_token_prob'] = prob_over_tokens[next_token]

  return output_tokens

# %%
# Expected output:
# "The best thing about Bath is that they don't even change or shrink anymore."

set_seed(0)
input_txt = "The best thing about Bath is"
input_tokens = tokenizer(input_txt, return_tensors='pt')
for i in range(10):
    input_tokens = sample_next_token(input_tokens, model, tokenizer)
    print(tokenizer.decode(input_tokens["input_ids"][0], skip_special_tokens=True))
# Out:
# /tmp/ipykernel_2033/2134723288.py:15: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:253.)
#   output_tokens["input_ids"] = torch.cat((output_tokens['input_ids'],torch.tensor([next_token])),dim=1)
# The best thing about Bath is that
# The best thing about Bath is that they
# The best thing about Bath is that they don
# The best thing about Bath is that they don't
# The best thing about Bath is that they don't even
# The best thing about Bath is that they don't even change
# The best thing about Bath is that they don't even change or
# The best thing about Bath is that they don't even change or shrink
# The best thing about Bath is that they don't even change or shrink anymore
# The best thing about Bath is that they don't even change or shrink anymore.

# %%
# TODO Modify the code below by changing the number of tokens generated and the initial sentence
# to get a feel for how well this works.  Since I didn't reset the seed, it will give a different
# answer every time that you run it.

# TODO Experiment with changing this line:
input_txt = "The best thing"
input_tokens = tokenizer(input_txt, return_tensors='pt')
# TODO Experiment with changing this line:
for i in range(25):
    input_tokens = sample_next_token(input_tokens, model, tokenizer)
    print(tokenizer.decode(input_tokens["input_ids"][0], skip_special_tokens=True))
# Out:
# The best thing about
# The best thing about our
# The best thing about our shots
# The best thing about our shots this
# The best thing about our shots this Labor
# The best thing about our shots this Labor Day
# The best thing about our shots this Labor Day,
# The best thing about our shots this Labor Day, with
# The best thing about our shots this Labor Day, with particular
# The best thing about our shots this Labor Day, with particular in
# The best thing about our shots this Labor Day, with particular in light
# The best thing about our shots this Labor Day, with particular in light of
# The best thing about our shots this Labor Day, with particular in light of the
# The best thing about our shots this Labor Day, with particular in light of the do
# The best thing about our shots this Labor Day, with particular in light of the doomsday
# The best thing about our shots this Labor Day, with particular in light of the doomsday threat
# The best thing about our shots this Labor Day, with particular in light of the doomsday threat of
# The best thing about our shots this Labor Day, with particular in light of the doomsday threat of Timothy
# The best thing about our shots this Labor Day, with particular in light of the doomsday threat of Timothy Mc
# The best thing about our shots this Labor Day, with particular in light of the doomsday threat of Timothy McVe
# The best thing about our shots this Labor Day, with particular in light of the doomsday threat of Timothy McVeigh
# The best thing about our shots this Labor Day, with particular in light of the doomsday threat of Timothy McVeigh's
# The best thing about our shots this Labor Day, with particular in light of the doomsday threat of Timothy McVeigh's Federal
# The best thing about our shots this Labor Day, with particular in light of the doomsday threat of Timothy McVeigh's Federal Defense
# The best thing about our shots this Labor Day, with particular in light of the doomsday threat of Timothy McVeigh's Federal Defense Authorization

# %% [markdown]
# # Greedy token selection
#
# You probably (correctly) got the impression that the text from pure sampling of the probability model can be kind of random.  How about if we choose most likely token at each step?

# %%
def get_best_next_token(input_tokens, model, tokenizer):
  # Run model to get prediction over next output
  outputs = model(input_ids = input_tokens['input_ids'], attention_mask = input_tokens['attention_mask'])
  # Find prediction
  prob_over_tokens = F.softmax(outputs.logits, dim=-1).detach().numpy()[0,-1]

  # TODO -- find the token index with the maximum probability
  # It should be returns as a list (i.e., put squared brackets around it)
  # Use https://numpy.org/doc/stable/reference/generated/numpy.argmax.html
  # Replace this line
  next_token = np.argmax(prob_over_tokens)


  # Append token to sentence
  output_tokens = input_tokens
  output_tokens["input_ids"] = torch.cat((output_tokens['input_ids'],torch.tensor([[next_token]])),dim=1)
  output_tokens['attention_mask'] = torch.cat((output_tokens['attention_mask'],torch.tensor([[1]])),dim=1)
  output_tokens['last_token_prob'] = prob_over_tokens[next_token]
  return output_tokens

# %%
# Expected output:
# The best thing about Bath is that it's a place where you can go to
set_seed(0)
input_txt = "The best thing about Bath is"
input_tokens = tokenizer(input_txt, return_tensors='pt')
for i in range(10):
    input_tokens = get_best_next_token(input_tokens, model, tokenizer)
    print(tokenizer.decode(input_tokens["input_ids"][0], skip_special_tokens=True))
# Out:
# The best thing about Bath is that
# The best thing about Bath is that it
# The best thing about Bath is that it's
# The best thing about Bath is that it's a
# The best thing about Bath is that it's a place
# The best thing about Bath is that it's a place where
# The best thing about Bath is that it's a place where you
# The best thing about Bath is that it's a place where you can
# The best thing about Bath is that it's a place where you can go
# The best thing about Bath is that it's a place where you can go to

# %%
# TODO Modify the code below by changing the number of tokens generated and the initial sentence
# to get a feel for how well this works.

# TODO Experiment with changing this line:
input_txt = "The best thing"
input_tokens = tokenizer(input_txt, return_tensors='pt')
# TODO Experiment with changing this line:
for i in range(16):
    input_tokens = get_best_next_token(input_tokens, model, tokenizer)
    print(tokenizer.decode(input_tokens["input_ids"][0], skip_special_tokens=True))
# Out:
# The best thing about
# The best thing about this
# The best thing about this is
# The best thing about this is that
# The best thing about this is that it
# The best thing about this is that it's
# The best thing about this is that it's a
# The best thing about this is that it's a very
# The best thing about this is that it's a very simple
# The best thing about this is that it's a very simple and
# The best thing about this is that it's a very simple and easy
# The best thing about this is that it's a very simple and easy way
# The best thing about this is that it's a very simple and easy way to
# The best thing about this is that it's a very simple and easy way to get
# The best thing about this is that it's a very simple and easy way to get started
# The best thing about this is that it's a very simple and easy way to get started.

# %% [markdown]
# # Top-K sampling
#
# You probably noticed that the greedy strategy produces quite realistic text, but it's kind of boring.  It produces generic answers.  Also, if this was a chatbot, then we wouldn't necessarily want it to produce the same answer to a question each time.
#
# Top-K sampling is a compromise strategy that samples randomly from the top K most probable tokens.  We could just choose them with a uniform distribution, or (as here) we could sample them according to their original probabilities.

# %%
def get_top_k_token(input_tokens, model, tokenizer, k=20):
  # Run model to get prediction over next output
  outputs = model(input_ids = input_tokens['input_ids'], attention_mask = input_tokens['attention_mask'])
  # Find prediction
  prob_over_tokens = F.softmax(outputs.logits, dim=-1).detach().numpy()[0,-1]

  # Draw a sample from the top K most likely tokens.
  # Take copy of the probabilities and sort from largest to smallest (use np.sort)
  # TODO -- replace this line
  sorted_prob_over_tokens =  np.sort(prob_over_tokens)[::-1]

  # Find the probability at the k'th position
  # TODO -- replace this line
  kth_prob_value = sorted_prob_over_tokens[k]

  # Set all probabilities below this value to zero
  prob_over_tokens[prob_over_tokens<kth_prob_value] = 0

  # Renormalize the probabilities so that they sum to one
  # TODO -- replace this line
  prob_over_tokens = prob_over_tokens / np.sum(prob_over_tokens)


  # Draw random token
  next_token = np.random.choice(len(prob_over_tokens), 1, replace=False, p=prob_over_tokens)

  # Append token to sentence
  output_tokens = input_tokens
  output_tokens["input_ids"] = torch.cat((output_tokens['input_ids'],torch.tensor([next_token])),dim=1)
  output_tokens['attention_mask'] = torch.cat((output_tokens['attention_mask'],torch.tensor([[1]])),dim=1)
  output_tokens['last_token_prob'] = prob_over_tokens[next_token]
  return output_tokens

# %%
# Expected output:
# The best thing about Bath is that you get to see all the beautiful faces of

set_seed(0)
input_txt = "The best thing about Bath is"
input_tokens = tokenizer(input_txt, return_tensors='pt')
for i in range(10):
    input_tokens = get_top_k_token(input_tokens, model, tokenizer, k=10)
    print(tokenizer.decode(input_tokens["input_ids"][0], skip_special_tokens=True))
# Out:
# The best thing about Bath is that
# The best thing about Bath is that you
# The best thing about Bath is that you get
# The best thing about Bath is that you get to
# The best thing about Bath is that you get to see
# The best thing about Bath is that you get to see all
# The best thing about Bath is that you get to see all the
# The best thing about Bath is that you get to see all the beautiful
# The best thing about Bath is that you get to see all the beautiful faces
# The best thing about Bath is that you get to see all the beautiful faces of

# %%
# TODO
# Experiment with different values of k
# If you set it to a lower number (say 3) the text will be less random
# If you set it to a higher number (say 5000) the text will be more random

set_seed(0)
input_txt = "The best thing about Bath is"
input_tokens = tokenizer(input_txt, return_tensors='pt')
for i in range(90):
    input_tokens = get_top_k_token(input_tokens, model, tokenizer, k=10)
    print(tokenizer.decode(input_tokens["input_ids"][0], skip_special_tokens=True))
# Out:
# The best thing about Bath is that
# The best thing about Bath is that you
# The best thing about Bath is that you get
# The best thing about Bath is that you get to
# The best thing about Bath is that you get to see
# The best thing about Bath is that you get to see all
# The best thing about Bath is that you get to see all the
# The best thing about Bath is that you get to see all the beautiful
# The best thing about Bath is that you get to see all the beautiful faces
# The best thing about Bath is that you get to see all the beautiful faces of
# The best thing about Bath is that you get to see all the beautiful faces of our
# The best thing about Bath is that you get to see all the beautiful faces of our students
# The best thing about Bath is that you get to see all the beautiful faces of our students and
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty,
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there.
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus,
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the people
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the people you
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the people you care
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the people you care about
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the people you care about.
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the people you care about. Bath
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the people you care about. Bath is
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the people you care about. Bath is a
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the people you care about. Bath is a great
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the people you care about. Bath is a great place
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the people you care about. Bath is a great place to
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the people you care about. Bath is a great place to live
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the people you care about. Bath is a great place to live,
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the people you care about. Bath is a great place to live, to
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the people you care about. Bath is a great place to live, to be
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the people you care about. Bath is a great place to live, to be with
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the people you care about. Bath is a great place to live, to be with your
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the people you care about. Bath is a great place to live, to be with your family
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the people you care about. Bath is a great place to live, to be with your family,
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the people you care about. Bath is a great place to live, to be with your family, and
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the people you care about. Bath is a great place to live, to be with your family, and to
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the people you care about. Bath is a great place to live, to be with your family, and to share
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the people you care about. Bath is a great place to live, to be with your family, and to share the
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the people you care about. Bath is a great place to live, to be with your family, and to share the joy
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the people you care about. Bath is a great place to live, to be with your family, and to share the joy of
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the people you care about. Bath is a great place to live, to be with your family, and to share the joy of learning
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the people you care about. Bath is a great place to live, to be with your family, and to share the joy of learning and
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the people you care about. Bath is a great place to live, to be with your family, and to share the joy of learning and learning
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the people you care about. Bath is a great place to live, to be with your family, and to share the joy of learning and learning,
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the people you care about. Bath is a great place to live, to be with your family, and to share the joy of learning and learning, and
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the people you care about. Bath is a great place to live, to be with your family, and to share the joy of learning and learning, and to
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the people you care about. Bath is a great place to live, to be with your family, and to share the joy of learning and learning, and to be
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the people you care about. Bath is a great place to live, to be with your family, and to share the joy of learning and learning, and to be a
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the people you care about. Bath is a great place to live, to be with your family, and to share the joy of learning and learning, and to be a part
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the people you care about. Bath is a great place to live, to be with your family, and to share the joy of learning and learning, and to be a part of
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the people you care about. Bath is a great place to live, to be with your family, and to share the joy of learning and learning, and to be a part of a
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the people you care about. Bath is a great place to live, to be with your family, and to share the joy of learning and learning, and to be a part of a community
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the people you care about. Bath is a great place to live, to be with your family, and to share the joy of learning and learning, and to be a part of a community that
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the people you care about. Bath is a great place to live, to be with your family, and to share the joy of learning and learning, and to be a part of a community that is
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the people you care about. Bath is a great place to live, to be with your family, and to share the joy of learning and learning, and to be a part of a community that is growing
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the people you care about. Bath is a great place to live, to be with your family, and to share the joy of learning and learning, and to be a part of a community that is growing.
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the people you care about. Bath is a great place to live, to be with your family, and to share the joy of learning and learning, and to be a part of a community that is growing.
#
# The best thing about Bath is that you get to see all the beautiful faces of our students and faculty, and the amazing staff who live there. You can see the diversity of what's happening on campus, and you can hear all the stories you can hear from the people you care about. Bath is a great place to live, to be with your family, and to share the joy of learning and learning, and to be a part of a community that is growing.

# %% [markdown]
# # Nucleus sampling
#
# Top-K sampling has the disadvantage that sometimes there are only a few plausible next tokens, and sometimes there are a lot.  How do we adapt to this situation?  One way is to sample from a fixed proportion of the probability mass.  That is we order the tokens in terms of probability and cut off the possibility of sampling when the cumulative sum is greater than a threshold.
#
# This way, we adapt the number of possible tokens that we can choose.

# %%
def get_nucleus_sampling_token(input_tokens, model, tokenizer, thresh=0.25):
  # Run model to get prediction over next output
  outputs = model(input_ids = input_tokens['input_ids'], attention_mask = input_tokens['attention_mask'])
  # Find prediction
  prob_over_tokens = F.softmax(outputs.logits, dim=-1).detach().numpy()[0,-1]

  # Find the most likely tokens that make up the first (thresh) of the probability
  # TODO -- sort the probabilities in decreasing order
  # Replace this line
  sorted_probs_decreasing = np.sort(prob_over_tokens)[::-1]
  # TODO -- compute the cumulative sum of these probabilities
  # Replace this line
  cum_sum_probs = np.sum(sorted_probs_decreasing)



  # Find index where that the cumulative sum is greater than the threshold
  thresh_index = np.argmax(cum_sum_probs>thresh)
  print("Choosing from %d tokens"%(thresh_index))
  # TODO:  Find the probability value to threshold
  # Replace this line:
  thresh_prob = prob_over_tokens[thresh_index]



  # Set any probabilities less than this to zero
  prob_over_tokens[prob_over_tokens<thresh_prob] = 0
  # Renormalize
  prob_over_tokens = prob_over_tokens / np.sum(prob_over_tokens)
  # Draw random token
  next_token = np.random.choice(len(prob_over_tokens), 1, replace=False, p=prob_over_tokens)

  # Append token to sentence
  output_tokens = input_tokens
  output_tokens["input_ids"] = torch.cat((output_tokens['input_ids'],torch.tensor([next_token])),dim=1)
  output_tokens['attention_mask'] = torch.cat((output_tokens['attention_mask'],torch.tensor([[1]])),dim=1)
  output_tokens['last_token_prob'] = prob_over_tokens[next_token]
  return output_tokens

# %%
# Expected output:
# The best thing about Bath is that it's not a city that has been around
set_seed(0)
input_txt = "The best thing about Bath is"
input_tokens = tokenizer(input_txt, return_tensors='pt')
for i in range(10):
    input_tokens = get_nucleus_sampling_token(input_tokens, model, tokenizer, thresh = 0.2)
    print(tokenizer.decode(input_tokens["input_ids"][0], skip_special_tokens=True))
# Out:
# Choosing from 0 tokens
# The best thing about Bath is that
# Choosing from 0 tokens
# The best thing about Bath is that we
# Choosing from 0 tokens
# The best thing about Bath is that we're
# Choosing from 0 tokens
# The best thing about Bath is that we're family
# Choosing from 0 tokens
# The best thing about Bath is that we're family-
# Choosing from 0 tokens
# The best thing about Bath is that we're family-friendly
# Choosing from 0 tokens
# The best thing about Bath is that we're family-friendly.
# Choosing from 0 tokens
# The best thing about Bath is that we're family-friendly. Ever
# Choosing from 0 tokens
# The best thing about Bath is that we're family-friendly. Ever hear
# Choosing from 0 tokens
# The best thing about Bath is that we're family-friendly. Ever hear of

# %%
# TODO -- experiment with setting the threshold probability to larger or smaller values
input_txt = "The best thing about Bath is"
input_tokens = tokenizer(input_txt, return_tensors='pt')
for i in range(80):
    input_tokens = get_nucleus_sampling_token(input_tokens, model, tokenizer, thresh = 0.2)
    print(tokenizer.decode(input_tokens["input_ids"][0], skip_special_tokens=True))
# Out:
# Choosing from 0 tokens
# The best thing about Bath is maybe
# Choosing from 0 tokens
# The best thing about Bath is maybe what
# Choosing from 0 tokens
# The best thing about Bath is maybe what you
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about S
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY.
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience.
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy.
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem is
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem is that
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem is that with
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem is that with T
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem is that with T.
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem is that with T.V
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem is that with T.V.
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem is that with T.V. and
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem is that with T.V. and my
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem is that with T.V. and my BL
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem is that with T.V. and my BLK
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem is that with T.V. and my BLK series
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem is that with T.V. and my BLK series,
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem is that with T.V. and my BLK series, Kelly
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem is that with T.V. and my BLK series, Kelly has
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem is that with T.V. and my BLK series, Kelly has kinda
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem is that with T.V. and my BLK series, Kelly has kinda broken
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem is that with T.V. and my BLK series, Kelly has kinda broken our
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem is that with T.V. and my BLK series, Kelly has kinda broken our ass
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem is that with T.V. and my BLK series, Kelly has kinda broken our ass.
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem is that with T.V. and my BLK series, Kelly has kinda broken our ass. I
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem is that with T.V. and my BLK series, Kelly has kinda broken our ass. I don
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem is that with T.V. and my BLK series, Kelly has kinda broken our ass. I don't
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem is that with T.V. and my BLK series, Kelly has kinda broken our ass. I don't know
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem is that with T.V. and my BLK series, Kelly has kinda broken our ass. I don't know if
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem is that with T.V. and my BLK series, Kelly has kinda broken our ass. I don't know if I
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem is that with T.V. and my BLK series, Kelly has kinda broken our ass. I don't know if I'm
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem is that with T.V. and my BLK series, Kelly has kinda broken our ass. I don't know if I'm talking
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem is that with T.V. and my BLK series, Kelly has kinda broken our ass. I don't know if I'm talking about
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem is that with T.V. and my BLK series, Kelly has kinda broken our ass. I don't know if I'm talking about new
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem is that with T.V. and my BLK series, Kelly has kinda broken our ass. I don't know if I'm talking about new or
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem is that with T.V. and my BLK series, Kelly has kinda broken our ass. I don't know if I'm talking about new or old
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem is that with T.V. and my BLK series, Kelly has kinda broken our ass. I don't know if I'm talking about new or old porn
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem is that with T.V. and my BLK series, Kelly has kinda broken our ass. I don't know if I'm talking about new or old porn,
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem is that with T.V. and my BLK series, Kelly has kinda broken our ass. I don't know if I'm talking about new or old porn, but
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem is that with T.V. and my BLK series, Kelly has kinda broken our ass. I don't know if I'm talking about new or old porn, but I
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem is that with T.V. and my BLK series, Kelly has kinda broken our ass. I don't know if I'm talking about new or old porn, but I really
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem is that with T.V. and my BLK series, Kelly has kinda broken our ass. I don't know if I'm talking about new or old porn, but I really like
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem is that with T.V. and my BLK series, Kelly has kinda broken our ass. I don't know if I'm talking about new or old porn, but I really like T
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem is that with T.V. and my BLK series, Kelly has kinda broken our ass. I don't know if I'm talking about new or old porn, but I really like T.
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem is that with T.V. and my BLK series, Kelly has kinda broken our ass. I don't know if I'm talking about new or old porn, but I really like T.V
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem is that with T.V. and my BLK series, Kelly has kinda broken our ass. I don't know if I'm talking about new or old porn, but I really like T.V."
# Choosing from 0 tokens
# The best thing about Bath is maybe what you really like about SONY. We get first hand experience. They don't bother us for what we are doing and we are good at what we enjoy. The only problem is that with T.V. and my BLK series, Kelly has kinda broken our ass. I don't know if I'm talking about new or old porn, but I really like T.V."N

# %% [markdown]
# # Beam search
#
# All of the methods we've seen so far choose the tokens one by one.  But this isn't necessarily sensible.  Even greedily choosing the best token doesn't necessarily retrieve the sequence with the highest probability.  It might be that the most likely token only has very unlikely tokens following it.
#
# Beam search maintains $K$ hypotheses about the best possible continuation.  It starts with the top $K$ continuations.  Then for each of those, it finds the top K continuations, giving $K^2$ hypotheses.  Then it retains just the top $K$ of these so that the number of hypotheses stays the same.

# %%
# This routine returns the k'th most likely next token.
# If k =0 then it returns the most likely token, if k=1 it returns the next most likely and so on
# We will need this for beam search
def get_kth_most_likely_token(input_tokens, model, tokenizer, k):
  # Run model to get prediction over next output
  outputs = model(input_ids = input_tokens['input_ids'], attention_mask = input_tokens['attention_mask'])
  # Find prediction
  prob_over_tokens = F.softmax(outputs.logits, dim=-1).detach().numpy()[0,-1]

  # Find the k'th most likely token
  # TODO Sort the probabilities from largest to smallest
  # Replace this line:
  sorted_prob_over_tokens = np.sort(prob_over_tokens)[::-1]
  # TODO Find the k'th sorted probability
  # Replace this line
  kth_prob_value = sorted_prob_over_tokens[k]



  # Find position of this token.
  next_token = np.where(prob_over_tokens == kth_prob_value)[0]

  # Append token to sentence
  output_tokens = input_tokens
  output_tokens["input_ids"] = torch.cat((output_tokens['input_ids'],torch.tensor([next_token])),dim=1)
  output_tokens['attention_mask'] = torch.cat((output_tokens['attention_mask'],torch.tensor([[1]])),dim=1)
  output_tokens['last_token_prob'] = prob_over_tokens[next_token]
  output_tokens['log_prob'] = output_tokens['log_prob'] + np.log(prob_over_tokens[next_token])
  return output_tokens

# %%
# We can test this code and see that if we choose the 2nd most likely (K=1) token each time
# then we get much better generation results than if we choose the 2001st most likely token

# Expected output:
# The best thing about Bath is the way you get the most bang outta the
set_seed(0)
input_txt = "The best thing about Bath is"
input_tokens = tokenizer(input_txt, return_tensors='pt')
input_tokens['log_prob'] = 0.0
for i in range(10):
    input_tokens = get_kth_most_likely_token(input_tokens, model, tokenizer, k=1)
    print(tokenizer.decode(input_tokens["input_ids"][0], skip_special_tokens=True))

# Expected output:
# The best thing about Bath is mixed profits partnerships» buy generic+ Honda throttlecont
input_txt = "The best thing about Bath is"
input_tokens = tokenizer(input_txt, return_tensors='pt')
input_tokens['log_prob'] = 0.0
for i in range(10):
    input_tokens = get_kth_most_likely_token(input_tokens, model, tokenizer, k=2000)
    print(tokenizer.decode(input_tokens["input_ids"][0], skip_special_tokens=True))

# TODO -- play around with different values of K
# Out:
# The best thing about Bath is the
# The best thing about Bath is the way
# The best thing about Bath is the way you
# The best thing about Bath is the way you get
# The best thing about Bath is the way you get the
# The best thing about Bath is the way you get the most
# The best thing about Bath is the way you get the most bang
# The best thing about Bath is the way you get the most bang out
# The best thing about Bath is the way you get the most bang outta
# The best thing about Bath is the way you get the most bang outta the
# The best thing about Bath is mixed
# The best thing about Bath is mixed profits
# The best thing about Bath is mixed profits partnerships
# The best thing about Bath is mixed profits partnerships»
# The best thing about Bath is mixed profits partnerships» buy
# The best thing about Bath is mixed profits partnerships» buy generic
# The best thing about Bath is mixed profits partnerships» buy generic+
# The best thing about Bath is mixed profits partnerships» buy generic+ Honda
# The best thing about Bath is mixed profits partnerships» buy generic+ Honda throttle
# The best thing about Bath is mixed profits partnerships» buy generic+ Honda throttlecont

# %%
# Print out each beam plus the log probability
def print_beams(beams):
  for index,beam in enumerate(beams):
    print("Beam %d, Prob %3.3f: "%(index,beam['log_prob'])+tokenizer.decode(beam["input_ids"][0], skip_special_tokens=True))
  print('---')


# TODO:  Read this code carefully!
def do_beam_search(input_tokens_in, model, tokenizer, n_beam=5, beam_length=10):
  # Store beams in a list
  input_tokens['log_prob'] = 0.0

  # Initialize with n_beam most likely continuations
  beams = [None] * n_beam
  for c_k in range(n_beam):
    beams[c_k] = dict(input_tokens_in)
    beams[c_k] = get_kth_most_likely_token(beams[c_k], model, tokenizer, c_k)

  print_beams(beams)

  # For each token in the sequence we will add
  for c_pos in range(beam_length-1):
    # Now for each beam, we continue it in the most likely ways, making n_beam*n_beam type hypotheses
    beams_all = [None] * (n_beam*n_beam)
    log_probs_all = np.zeros(n_beam*n_beam)
    # For each current hypothesis
    for c_beam in range(n_beam):
      # For each continuation
      for c_k in range(n_beam):
        # Store the continuation and the probability
        beams_all[c_beam * n_beam + c_k] = dict(get_kth_most_likely_token(beams[c_beam], model, tokenizer, c_k))
        log_probs_all[c_beam * n_beam + c_k] = beams_all[c_beam * n_beam + c_k]['log_prob']

    # Keep the best n_beams sequences with the highest probabilities
    sorted_index = np.argsort(np.array(log_probs_all)*-1)
    for c_k in range(n_beam):
      beams[c_k] = dict(beams_all[sorted_index[c_k]])

    # Print the beams
    print_beams(beams)

  return beams[0]

# %%
# Expected output:
# The best thing about Bath is that it's a place where you don't have to

set_seed(0)
input_txt = "The best thing about Bath is"
input_tokens = tokenizer(input_txt, return_tensors='pt')

# Now let's call the beam search
# It takes a while as it has to run the model multiple times to add a token
n_beams = 5
best_beam = do_beam_search(input_tokens,model,tokenizer)
print("Beam search result:")
print(tokenizer.decode(best_beam["input_ids"][0], skip_special_tokens=True))

# You should see that the best answer is not the same as the greedy solution we found above
# Out:
# /tmp/ipykernel_2033/4010751250.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Beam %d, Prob %3.3f: "%(index,beam['log_prob'])+tokenizer.decode(beam["input_ids"][0], skip_special_tokens=True))
# /tmp/ipykernel_2033/4010751250.py:32: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   log_probs_all[c_beam * n_beam + c_k] = beams_all[c_beam * n_beam + c_k]['log_prob']
# Beam 0, Prob -0.727: The best thing about Bath is that
# Beam 1, Prob -2.161: The best thing about Bath is the
# Beam 2, Prob -3.177: The best thing about Bath is it
# Beam 3, Prob -3.468: The best thing about Bath is how
# Beam 4, Prob -3.536: The best thing about Bath is you
# ---
# Beam 0, Prob -1.899: The best thing about Bath is that it
# Beam 1, Prob -3.931: The best thing about Bath is it's
# Beam 2, Prob -4.079: The best thing about Bath is that it is
# Beam 3, Prob -4.433: The best thing about Bath is the fact
# Beam 4, Prob -4.553: The best thing about Bath is you can
# ---
# Beam 0, Prob -2.740: The best thing about Bath is that it's
# Beam 1, Prob -4.657: The best thing about Bath is the fact that
# Beam 2, Prob -5.331: The best thing about Bath is that it's not
# Beam 3, Prob -6.227: The best thing about Bath is it's a
# Beam 4, Prob -6.264: The best thing about Bath is that it is a
# ---
# Beam 0, Prob -4.938: The best thing about Bath is that it's a
# Beam 1, Prob -6.012: The best thing about Bath is the fact that it
# Beam 2, Prob -7.313: The best thing about Bath is that it's not a
# Beam 3, Prob -7.907: The best thing about Bath is the fact that it is
# Beam 4, Prob -8.110: The best thing about Bath is that it's a great
# ---
# Beam 0, Prob -6.919: The best thing about Bath is the fact that it's
# Beam 1, Prob -7.764: The best thing about Bath is that it's a place
# Beam 2, Prob -8.930: The best thing about Bath is that it's a great place
# Beam 3, Prob -9.479: The best thing about Bath is that it's a place that
# Beam 4, Prob -9.543: The best thing about Bath is the fact that it's not
# ---
# Beam 0, Prob -8.451: The best thing about Bath is that it's a place where
# Beam 1, Prob -9.125: The best thing about Bath is the fact that it's a
# Beam 2, Prob -9.285: The best thing about Bath is that it's a great place to
# Beam 3, Prob -10.536: The best thing about Bath is that it's a place where people
# Beam 4, Prob -11.255: The best thing about Bath is that it's a place that's
# ---
# Beam 0, Prob -9.306: The best thing about Bath is that it's a place where you
# Beam 1, Prob -11.327: The best thing about Bath is that it's a place where people can
# Beam 2, Prob -11.839: The best thing about Bath is that it's a great place to live
# Beam 3, Prob -12.031: The best thing about Bath is that it's a place where you don
# Beam 4, Prob -12.366: The best thing about Bath is the fact that it's a place
# ---
# Beam 0, Prob -9.753: The best thing about Bath is that it's a place where you can
# Beam 1, Prob -12.031: The best thing about Bath is that it's a place where you don't
# Beam 2, Prob -12.629: The best thing about Bath is that it's a place where you can get
# Beam 3, Prob -13.006: The best thing about Bath is that it's a great place to live.
# Beam 4, Prob -13.108: The best thing about Bath is the fact that it's a place where
# ---
# Beam 0, Prob -12.274: The best thing about Bath is that it's a place where you can go
# Beam 1, Prob -12.603: The best thing about Bath is that it's a place where you don't have
# Beam 2, Prob -14.056: The best thing about Bath is the fact that it's a place where you
# Beam 3, Prob -14.324: The best thing about Bath is that it's a place where you can go and
# Beam 4, Prob -14.492: The best thing about Bath is that it's a great place to live. It
# ---
# Beam 0, Prob -12.662: The best thing about Bath is that it's a place where you don't have to
# Beam 1, Prob -13.658: The best thing about Bath is that it's a place where you can go to
# Beam 2, Prob -14.469: The best thing about Bath is the fact that it's a place where you can
# Beam 3, Prob -14.785: The best thing about Bath is that it's a great place to live. It's
# Beam 4, Prob -14.896: The best thing about Bath is that it's a place where you don't have to be
# ---
# Beam search result:
# The best thing about Bath is that it's a place where you don't have to

# %% [markdown]
# You can read about more decoding strategies in this blog (which uses a recursive neural network, not a transformer, but the principles are the same).
#
# https://www.borealisai.com/research-blogs/tutorial-6-neural-natural-language-generation-decoding-algorithms/
#
# You can also look at other possible language models via hugging face:
#
# https://huggingface.co/docs/transformers/v4.25.1/en/model_summary#decoders-or-autoregressive-models
