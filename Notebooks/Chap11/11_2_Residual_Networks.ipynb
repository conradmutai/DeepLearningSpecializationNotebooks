# %% [markdown]
# <a href="https://colab.research.google.com/github/conradmutai/DeepLearningSpecializationNotebooks/blob/main/Notebooks/Chap11/11_2_Residual_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-82c37y2r
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-82c37y2r
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=cf055ff9f547a3b80c9347b88040d147d3b090aaf1bccbd1e6f71562097bf410
#   Stored in directory: /tmp/pip-ephem-wheel-cache-c3441t61/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# We will adapt this model to have residual connections around the linear layers
# This is the same model we used in practical 8.1, but we can't use the sequential
# class for residual networks (which aren't strictly sequential).  Hence, I've rewritten
# it as a model that inherits from a base class

class ResidualNetwork(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100):
    super(ResidualNetwork, self).__init__()
    self.linear1 = nn.Linear(input_size, hidden_size)
    self.linear2 = nn.Linear(hidden_size, hidden_size)
    self.linear3 = nn.Linear(hidden_size, hidden_size)
    self.linear4 = nn.Linear(hidden_size, output_size)
    print("Initialized MLPBase model with {} parameters".format(self.count_params()))

  def count_params(self):
    return sum([p.view(-1).shape[0] for p in self.parameters()])

# TODO -- Add residual connections to this model
# The order of operations within each block should similar to figure 11.5b
# ie., linear1 first, ReLU+linear2 in first residual block, ReLU+linear3 in second residual block), linear4 at end
# Replace this function
  def forward(self, x):
    h1 = self.linear1(x).relu()
    h2 = self.linear2(h1) + self.linear2(h1).relu()
    h3 = self.linear3(h2) + self.linear3(h2).relu()
    return self.linear4(h3)


class LinearNetwork(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100):
    super(Sequential)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.800433, train error 64.05,  val loss 1.869364, percent error 63.40
# Epoch     1, train loss 1.401423, train error 54.05,  val loss 1.491009, percent error 54.60
# Epoch     2, train loss 1.064241, train error 40.33,  val loss 1.170173, percent error 46.00
# Epoch     3, train loss 0.888271, train error 34.03,  val loss 1.065081, percent error 41.50
# Epoch     4, train loss 0.815018, train error 31.75,  val loss 1.062714, percent error 40.10
# Epoch     5, train loss 0.786119, train error 30.82,  val loss 1.006081, percent error 39.80
# Epoch     6, train loss 0.701240, train error 26.72,  val loss 0.949736, percent error 35.70
# Epoch     7, train loss 0.632538, train error 24.10,  val loss 0.943241, percent error 33.90
# Epoch     8, train loss 0.605661, train error 23.22,  val loss 0.942598, percent error 35.40
# Epoch     9, train loss 0.591566, train error 22.10,  val loss 1.057791, percent error 37.80
# Epoch    10, train loss 0.533902, train error 20.47,  val loss 1.041842, percent error 33.30
# Epoch    11, train loss 0.603741, train error 23.35,  val loss 1.176139, percent error 39.20
# Epoch    12, train loss 0.509395, train error 18.97,  val loss 0.997351, percent error 35.00
# Epoch    13, train loss 0.506087, train error 19.43,  val loss 1.021189, percent error 34.70
# Epoch    14, train loss 0.465449, train error 17.93,  val loss 1.085210, percent error 34.50
# Epoch    15, train loss 0.521865, train error 20.07,  val loss 1.146739, percent error 36.60
# Epoch    16, train loss 0.412595, train error 16.18,  val loss 0.987849, percent error 32.90
# Epoch    17, train loss 0.426207, train error 16.32,  val loss 1.060688, percent error 35.30
# Epoch    18, train loss 0.495627, train error 18.10,  val loss 1.198759, percent error 35.80
# Epoch    19, train loss 0.400643, train error 15.05,  val loss 1.035903, percent error 32.30
# Epoch    20, train loss 0.207031, train error 6.50,  val loss 0.954930, percent error 29.80
# Epoch    21, train loss 0.158531, train error 5.07,  val loss 1.022640, percent error 29.50
# Epoch    22, train loss 0.119542, train error 3.47,  val loss 1.082769, percent error 30.10
# Epoch    23, train loss 0.123046, train error 4.07,  val loss 1.156877, percent error 31.50
# Epoch    24, train loss 0.092861, train error 2.82,  val loss 1.238551, percent error 30.50
# Epoch    25, train loss 0.076563, train error 2.05,  val loss 1.289698, percent error 30.30
# Epoch    26, train loss 0.073124, train error 1.95,  val loss 1.407416, percent error 30.00
# Epoch    27, train loss 0.069671, train error 2.10,  val loss 1.494817, percent error 29.20
# Epoch    28, train loss 0.063533, train error 1.68,  val loss 1.481013, percent error 29.10
# Epoch    29, train loss 0.085929, train error 2.75,  val loss 1.542438, percent error 30.40
# Epoch    30, train loss 0.089765, train error 2.88,  val loss 1.551344, percent error 30.20
# Epoch    31, train loss 0.117848, train error 3.93,  val loss 1.654307, percent error 29.90
# Epoch    32, train loss 0.137519, train error 5.00,  val loss 1.675254, percent error 30.10
# Epoch    33, train loss 0.198007, train error 6.82,  val loss 1.664082, percent error 31.20
# Epoch    34, train loss 0.190698, train error 6.95,  val loss 1.627347, percent error 31.10
# Epoch    35, train loss 0.110138, train error 3.35,  val loss 1.391241, percent error 30.20
# Epoch    36, train loss 0.100758, train error 4.05,  val loss 1.443587, percent error 28.30
# Epoch    37, train loss 0.069306, train error 2.30,  val loss 1.397576, percent error 28.50
# Epoch    38, train loss 0.045112, train error 1.00,  val loss 1.475957, percent error 28.10
# Epoch    39, train loss 0.027377, train error 0.38,  val loss 1.471813, percent error 27.30
# Epoch    40, train loss 0.015095, train error 0.03,  val loss 1.463474, percent error 26.70
# Epoch    41, train loss 0.011024, train error 0.03,  val loss 1.512493, percent error 27.10
# Epoch    42, train loss 0.009243, train error 0.03,  val loss 1.536489, percent error 26.90
# Epoch    43, train loss 0.008100, train error 0.03,  val loss 1.566503, percent error 27.30
# Epoch    44, train loss 0.007342, train error 0.00,  val loss 1.594553, percent error 26.70
# Epoch    45, train loss 0.006796, train error 0.00,  val loss 1.620044, percent error 26.80
# Epoch    46, train loss 0.006110, train error 0.00,  val loss 1.645363, percent error 26.90
# Epoch    47, train loss 0.005688, train error 0.00,  val loss 1.661612, percent error 26.70
# Epoch    48, train loss 0.005195, train error 0.00,  val loss 1.683517, percent error 27.10
# Epoch    49, train loss 0.004809, train error 0.00,  val loss 1.698557, percent error 27.20
# Epoch    50, train loss 0.004515, train error 0.00,  val loss 1.720481, percent error 26.90
# Epoch    51, train loss 0.004256, train error 0.00,  val loss 1.735335, percent error 26.90
# Epoch    52, train loss 0.004024, train error 0.00,  val loss 1.749860, percent error 27.00
# Epoch    53, train loss 0.003858, train error 0.00,  val loss 1.769176, percent error 26.70
# Epoch    54, train loss 0.003601, train error 0.00,  val loss 1.784209, percent error 26.90
# Epoch    55, train loss 0.003428, train error 0.00,  val loss 1.793864, percent error 27.30
# Epoch    56, train loss 0.003267, train error 0.00,  val loss 1.811302, percent error 27.00
# Epoch    57, train loss 0.003119, train error 0.00,  val loss 1.822773, percent error 27.20
# Epoch    58, train loss 0.002991, train error 0.00,  val loss 1.836973, percent error 27.20
# Epoch    59, train loss 0.002872, train error 0.00,  val loss 1.848825, percent error 27.10
# Epoch    60, train loss 0.002800, train error 0.00,  val loss 1.853948, percent error 27.20
# Epoch    61, train loss 0.002745, train error 0.00,  val loss 1.859870, percent error 27.10
# Epoch    62, train loss 0.002692, train error 0.00,  val loss 1.865317, percent error 27.20
# Epoch    63, train loss 0.002643, train error 0.00,  val loss 1.870742, percent error 27.40
# Epoch    64, train loss 0.002595, train error 0.00,  val loss 1.876609, percent error 27.30
# Epoch    65, train loss 0.002548, train error 0.00,  val loss 1.881704, percent error 27.20
# Epoch    66, train loss 0.002504, train error 0.00,  val loss 1.886342, percent error 27.10
# Epoch    67, train loss 0.002461, train error 0.00,  val loss 1.892890, percent error 27.20
# Epoch    68, train loss 0.002418, train error 0.00,  val loss 1.898208, percent error 27.10
# Epoch    69, train loss 0.002377, train error 0.00,  val loss 1.902445, percent error 27.40
# Epoch    70, train loss 0.002337, train error 0.00,  val loss 1.908406, percent error 27.20
# Epoch    71, train loss 0.002298, train error 0.00,  val loss 1.913234, percent error 27.20
# Epoch    72, train loss 0.002261, train error 0.00,  val loss 1.916997, percent error 27.20
# Epoch    73, train loss 0.002225, train error 0.00,  val loss 1.923015, percent error 27.20
# Epoch    74, train loss 0.002191, train error 0.00,  val loss 1.928233, percent error 27.20
# Epoch    75, train loss 0.002156, train error 0.00,  val loss 1.932539, percent error 27.30
# Epoch    76, train loss 0.002124, train error 0.00,  val loss 1.937084, percent error 27.40
# Epoch    77, train loss 0.002093, train error 0.00,  val loss 1.941843, percent error 27.30
# Epoch    78, train loss 0.002061, train error 0.00,  val loss 1.946622, percent error 27.20
# Epoch    79, train loss 0.002032, train error 0.00,  val loss 1.950168, percent error 27.40
# Epoch    80, train loss 0.002016, train error 0.00,  val loss 1.952887, percent error 27.40
# Epoch    81, train loss 0.002001, train error 0.00,  val loss 1.954932, percent error 27.30
# Epoch    82, train loss 0.001987, train error 0.00,  val loss 1.957544, percent error 27.40
# Epoch    83, train loss 0.001973, train error 0.00,  val loss 1.959397, percent error 27.30
# Epoch    84, train loss 0.001959, train error 0.00,  val loss 1.962101, percent error 27.40
# Epoch    85, train loss 0.001945, train error 0.00,  val loss 1.964075, percent error 27.40
# Epoch    86, train loss 0.001932, train error 0.00,  val loss 1.966418, percent error 27.40
# Epoch    87, train loss 0.001919, train error 0.00,  val loss 1.968492, percent error 27.30
# Epoch    88, train loss 0.001905, train error 0.00,  val loss 1.970494, percent error 27.40
# Epoch    89, train loss 0.001892, train error 0.00,  val loss 1.972239, percent error 27.40
# Epoch    90, train loss 0.001879, train error 0.00,  val loss 1.974566, percent error 27.40
# Epoch    91, train loss 0.001867, train error 0.00,  val loss 1.976669, percent error 27.40
# Epoch    92, train loss 0.001854, train error 0.00,  val loss 1.978768, percent error 27.40
# Epoch    93, train loss 0.001842, train error 0.00,  val loss 1.980846, percent error 27.40
# Epoch    94, train loss 0.001830, train error 0.00,  val loss 1.982962, percent error 27.30
# Epoch    95, train loss 0.001818, train error 0.00,  val loss 1.984605, percent error 27.40
# Epoch    96, train loss 0.001806, train error 0.00,  val loss 1.987180, percent error 27.30
# Epoch    97, train loss 0.001794, train error 0.00,  val loss 1.988884, percent error 27.50
# Epoch    98, train loss 0.001783, train error 0.00,  val loss 1.990802, percent error 27.40
# Epoch    99, train loss 0.001771, train error 0.00,  val loss 1.992984, percent error 27.40

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?
