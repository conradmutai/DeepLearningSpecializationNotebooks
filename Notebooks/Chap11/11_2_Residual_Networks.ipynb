# %% [markdown]
# <a href="https://colab.research.google.com/github/conradmutai/DeepLearningSpecializationNotebooks/blob/main/Notebooks/Chap11/11_2_Residual_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-82c37y2r
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-82c37y2r
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=cf055ff9f547a3b80c9347b88040d147d3b090aaf1bccbd1e6f71562097bf410
#   Stored in directory: /tmp/pip-ephem-wheel-cache-c3441t61/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# We will adapt this model to have residual connections around the linear layers
# This is the same model we used in practical 8.1, but we can't use the sequential
# class for residual networks (which aren't strictly sequential).  Hence, I've rewritten
# it as a model that inherits from a base class

class ResidualNetwork(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100):
    super(ResidualNetwork, self).__init__()
    self.linear1 = nn.Linear(input_size, hidden_size)
    self.linear2 = nn.Linear(hidden_size, hidden_size)
    self.linear3 = nn.Linear(hidden_size, hidden_size)
    self.linear4 = nn.Linear(hidden_size, output_size)
    print("Initialized MLPBase model with {} parameters".format(self.count_params()))

  def count_params(self):
    return sum([p.view(-1).shape[0] for p in self.parameters()])

# TODO -- Add residual connections to this model
# The order of operations within each block should similar to figure 11.5b
# ie., linear1 first, ReLU+linear2 in first residual block, ReLU+linear3 in second residual block), linear4 at end
# Replace this function
  def forward(self, x):
    h1 = self.linear1(x).relu()
    h2 = self.linear2(h1) + self.linear2(h1).relu()
    h3 = self.linear3(h2) + self.linear3(h2).relu()
    return self.linear4(h3)

  # def forwardNonResidual(self, x):
  #   h1 = self.linear1(x).relu()
  #   h2 = self.linear2(h1).relu()
  #   h3 = self.linear3(h2).relu()
  #   return self.linear4(h3)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(40, 10)
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.581210, train error 61.53,  val loss 1.635562, percent error 66.60
# Epoch     1, train loss 1.303585, train error 48.45,  val loss 1.418517, percent error 55.60
# Epoch     2, train loss 1.210136, train error 46.28,  val loss 1.407550, percent error 54.50
# Epoch     3, train loss 0.954928, train error 33.72,  val loss 1.218647, percent error 47.40
# Epoch     4, train loss 0.841325, train error 31.12,  val loss 1.182725, percent error 46.10
# Epoch     5, train loss 0.774549, train error 28.60,  val loss 1.153384, percent error 44.80
# Epoch     6, train loss 0.659438, train error 23.12,  val loss 1.114602, percent error 41.10
# Epoch     7, train loss 0.516090, train error 18.07,  val loss 1.101397, percent error 40.70
# Epoch     8, train loss 0.462160, train error 16.28,  val loss 1.133481, percent error 40.00
# Epoch     9, train loss 0.404217, train error 14.40,  val loss 1.121079, percent error 38.70
# Epoch    10, train loss 0.328422, train error 11.25,  val loss 1.197563, percent error 39.60
# Epoch    11, train loss 0.318623, train error 10.72,  val loss 1.301603, percent error 39.90
# Epoch    12, train loss 0.313516, train error 11.38,  val loss 1.356833, percent error 38.00
# Epoch    13, train loss 0.303335, train error 10.80,  val loss 1.287997, percent error 36.50
# Epoch    14, train loss 0.299321, train error 10.00,  val loss 1.452642, percent error 40.50
# Epoch    15, train loss 0.177974, train error 5.40,  val loss 1.278193, percent error 34.70
# Epoch    16, train loss 0.126118, train error 3.82,  val loss 1.272081, percent error 34.40
# Epoch    17, train loss 0.102638, train error 2.62,  val loss 1.327285, percent error 34.30
# Epoch    18, train loss 0.083140, train error 2.22,  val loss 1.454186, percent error 36.70
# Epoch    19, train loss 0.077523, train error 1.97,  val loss 1.476017, percent error 33.50
# Epoch    20, train loss 0.022048, train error 0.07,  val loss 1.377620, percent error 33.80
# Epoch    21, train loss 0.012455, train error 0.03,  val loss 1.386061, percent error 33.50
# Epoch    22, train loss 0.009578, train error 0.00,  val loss 1.417209, percent error 33.10
# Epoch    23, train loss 0.008050, train error 0.00,  val loss 1.450769, percent error 32.90
# Epoch    24, train loss 0.007083, train error 0.00,  val loss 1.462134, percent error 33.50
# Epoch    25, train loss 0.006330, train error 0.00,  val loss 1.486985, percent error 33.20
# Epoch    26, train loss 0.005779, train error 0.00,  val loss 1.498760, percent error 33.40
# Epoch    27, train loss 0.005309, train error 0.00,  val loss 1.514637, percent error 33.70
# Epoch    28, train loss 0.004914, train error 0.00,  val loss 1.530728, percent error 33.30
# Epoch    29, train loss 0.004577, train error 0.00,  val loss 1.543185, percent error 33.50
# Epoch    30, train loss 0.004317, train error 0.00,  val loss 1.552708, percent error 33.20
# Epoch    31, train loss 0.004059, train error 0.00,  val loss 1.565895, percent error 33.50
# Epoch    32, train loss 0.003830, train error 0.00,  val loss 1.579266, percent error 33.30
# Epoch    33, train loss 0.003622, train error 0.00,  val loss 1.588065, percent error 33.40
# Epoch    34, train loss 0.003442, train error 0.00,  val loss 1.600141, percent error 33.50
# Epoch    35, train loss 0.003281, train error 0.00,  val loss 1.607365, percent error 33.20
# Epoch    36, train loss 0.003142, train error 0.00,  val loss 1.616566, percent error 33.30
# Epoch    37, train loss 0.003002, train error 0.00,  val loss 1.625775, percent error 33.20
# Epoch    38, train loss 0.002886, train error 0.00,  val loss 1.633398, percent error 33.10
# Epoch    39, train loss 0.002785, train error 0.00,  val loss 1.642793, percent error 33.40
# Epoch    40, train loss 0.002711, train error 0.00,  val loss 1.646235, percent error 33.20
# Epoch    41, train loss 0.002661, train error 0.00,  val loss 1.649809, percent error 32.90
# Epoch    42, train loss 0.002612, train error 0.00,  val loss 1.654448, percent error 33.00
# Epoch    43, train loss 0.002565, train error 0.00,  val loss 1.657234, percent error 33.40
# Epoch    44, train loss 0.002520, train error 0.00,  val loss 1.661206, percent error 33.30
# Epoch    45, train loss 0.002476, train error 0.00,  val loss 1.664143, percent error 33.20
# Epoch    46, train loss 0.002434, train error 0.00,  val loss 1.667401, percent error 32.90
# Epoch    47, train loss 0.002393, train error 0.00,  val loss 1.670385, percent error 33.20
# Epoch    48, train loss 0.002353, train error 0.00,  val loss 1.673931, percent error 33.40
# Epoch    49, train loss 0.002315, train error 0.00,  val loss 1.677996, percent error 33.10
# Epoch    50, train loss 0.002278, train error 0.00,  val loss 1.680997, percent error 33.00
# Epoch    51, train loss 0.002243, train error 0.00,  val loss 1.683946, percent error 33.10
# Epoch    52, train loss 0.002208, train error 0.00,  val loss 1.687216, percent error 33.30
# Epoch    53, train loss 0.002174, train error 0.00,  val loss 1.689802, percent error 33.40
# Epoch    54, train loss 0.002141, train error 0.00,  val loss 1.693001, percent error 33.10
# Epoch    55, train loss 0.002110, train error 0.00,  val loss 1.696180, percent error 33.30
# Epoch    56, train loss 0.002079, train error 0.00,  val loss 1.698464, percent error 33.10
# Epoch    57, train loss 0.002048, train error 0.00,  val loss 1.701882, percent error 33.20
# Epoch    58, train loss 0.002019, train error 0.00,  val loss 1.704366, percent error 33.10
# Epoch    59, train loss 0.001991, train error 0.00,  val loss 1.706997, percent error 33.10
# Epoch    60, train loss 0.001977, train error 0.00,  val loss 1.708297, percent error 33.20
# Epoch    61, train loss 0.001963, train error 0.00,  val loss 1.709955, percent error 33.20
# Epoch    62, train loss 0.001950, train error 0.00,  val loss 1.711502, percent error 33.20
# Epoch    63, train loss 0.001936, train error 0.00,  val loss 1.712498, percent error 33.20
# Epoch    64, train loss 0.001923, train error 0.00,  val loss 1.713899, percent error 33.10
# Epoch    65, train loss 0.001910, train error 0.00,  val loss 1.715067, percent error 33.20
# Epoch    66, train loss 0.001898, train error 0.00,  val loss 1.716477, percent error 33.20
# Epoch    67, train loss 0.001885, train error 0.00,  val loss 1.717762, percent error 33.20
# Epoch    68, train loss 0.001873, train error 0.00,  val loss 1.719524, percent error 33.20
# Epoch    69, train loss 0.001860, train error 0.00,  val loss 1.720293, percent error 33.10
# Epoch    70, train loss 0.001848, train error 0.00,  val loss 1.722064, percent error 33.10
# Epoch    71, train loss 0.001836, train error 0.00,  val loss 1.722813, percent error 33.10
# Epoch    72, train loss 0.001824, train error 0.00,  val loss 1.724744, percent error 33.10
# Epoch    73, train loss 0.001813, train error 0.00,  val loss 1.725542, percent error 33.10
# Epoch    74, train loss 0.001801, train error 0.00,  val loss 1.726388, percent error 33.10
# Epoch    75, train loss 0.001790, train error 0.00,  val loss 1.727948, percent error 33.10
# Epoch    76, train loss 0.001779, train error 0.00,  val loss 1.729420, percent error 33.10
# Epoch    77, train loss 0.001768, train error 0.00,  val loss 1.730725, percent error 33.10
# Epoch    78, train loss 0.001757, train error 0.00,  val loss 1.731877, percent error 33.10
# Epoch    79, train loss 0.001746, train error 0.00,  val loss 1.732890, percent error 33.10
# Epoch    80, train loss 0.001740, train error 0.00,  val loss 1.733475, percent error 33.10
# Epoch    81, train loss 0.001735, train error 0.00,  val loss 1.734112, percent error 33.10
# Epoch    82, train loss 0.001730, train error 0.00,  val loss 1.734843, percent error 33.10
# Epoch    83, train loss 0.001724, train error 0.00,  val loss 1.735527, percent error 33.10
# Epoch    84, train loss 0.001719, train error 0.00,  val loss 1.735813, percent error 33.10
# Epoch    85, train loss 0.001714, train error 0.00,  val loss 1.736414, percent error 33.10
# Epoch    86, train loss 0.001709, train error 0.00,  val loss 1.737195, percent error 33.10
# Epoch    87, train loss 0.001704, train error 0.00,  val loss 1.737854, percent error 33.10
# Epoch    88, train loss 0.001699, train error 0.00,  val loss 1.738326, percent error 33.10
# Epoch    89, train loss 0.001694, train error 0.00,  val loss 1.738938, percent error 33.10
# Epoch    90, train loss 0.001689, train error 0.00,  val loss 1.739578, percent error 33.10
# Epoch    91, train loss 0.001684, train error 0.00,  val loss 1.740173, percent error 33.10
# Epoch    92, train loss 0.001679, train error 0.00,  val loss 1.740833, percent error 33.10
# Epoch    93, train loss 0.001674, train error 0.00,  val loss 1.741211, percent error 33.10
# Epoch    94, train loss 0.001669, train error 0.00,  val loss 1.742000, percent error 33.10
# Epoch    95, train loss 0.001664, train error 0.00,  val loss 1.742423, percent error 33.10
# Epoch    96, train loss 0.001659, train error 0.00,  val loss 1.742901, percent error 33.10
# Epoch    97, train loss 0.001654, train error 0.00,  val loss 1.743437, percent error 33.20
# Epoch    98, train loss 0.001649, train error 0.00,  val loss 1.744174, percent error 33.20
# Epoch    99, train loss 0.001645, train error 0.00,  val loss 1.744695, percent error 33.20

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?
