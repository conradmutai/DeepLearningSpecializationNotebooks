# %% [markdown]
# <a href="https://colab.research.google.com/github/conradmutai/DeepLearningSpecializationNotebooks/blob/main/Notebooks/Chap11/11_2_Residual_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-gb1bhs6u
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-gb1bhs6u
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# We will adapt this model to have residual connections around the linear layers
# This is the same model we used in practical 8.1, but we can't use the sequential
# class for residual networks (which aren't strictly sequential).  Hence, I've rewritten
# it as a model that inherits from a base class

class ResidualNetwork(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100):
    super(ResidualNetwork, self).__init__()
    self.linear1 = nn.Linear(input_size, hidden_size)
    self.linear2 = nn.Linear(hidden_size, hidden_size)
    self.linear3 = nn.Linear(hidden_size, hidden_size)
    self.linear4 = nn.Linear(hidden_size, output_size)
    print("Initialized MLPBase model with {} parameters".format(self.count_params()))

  def count_params(self):
    return sum([p.view(-1).shape[0] for p in self.parameters()])

# TODO -- Add residual connections to this model
# The order of operations within each block should similar to figure 11.5b
# ie., linear1 first, ReLU+linear2 in first residual block, ReLU+linear3 in second residual block), linear4 at end
# Replace this function
  def forward(self, x):
    h1 = self.linear1(x).relu()
    h2 = self.linear2(h1).relu()
    h3 = self.linear3(h2).relu()
    return self.linear4(h3)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.590404, train error 61.92,  val loss 1.652368, percent error 66.00
# Epoch     1, train loss 1.317315, train error 50.67,  val loss 1.461349, percent error 58.40
# Epoch     2, train loss 1.139643, train error 43.28,  val loss 1.349041, percent error 53.30
# Epoch     3, train loss 0.990527, train error 36.22,  val loss 1.251802, percent error 48.50
# Epoch     4, train loss 0.904940, train error 34.05,  val loss 1.265454, percent error 50.10
# Epoch     5, train loss 0.783525, train error 27.95,  val loss 1.209864, percent error 45.40
# Epoch     6, train loss 0.702670, train error 25.00,  val loss 1.232871, percent error 45.60
# Epoch     7, train loss 0.606523, train error 21.88,  val loss 1.169062, percent error 42.50
# Epoch     8, train loss 0.491526, train error 17.53,  val loss 1.168221, percent error 40.00
# Epoch     9, train loss 0.437066, train error 14.97,  val loss 1.224369, percent error 41.20
# Epoch    10, train loss 0.401306, train error 14.97,  val loss 1.255934, percent error 40.10
# Epoch    11, train loss 0.356217, train error 12.80,  val loss 1.348624, percent error 39.70
# Epoch    12, train loss 0.315347, train error 11.38,  val loss 1.397803, percent error 42.90
# Epoch    13, train loss 0.257157, train error 8.97,  val loss 1.332445, percent error 39.80
# Epoch    14, train loss 0.219790, train error 7.12,  val loss 1.402566, percent error 39.80
# Epoch    15, train loss 0.168893, train error 4.85,  val loss 1.401493, percent error 40.20
# Epoch    16, train loss 0.139082, train error 4.22,  val loss 1.462265, percent error 36.70
# Epoch    17, train loss 0.114412, train error 2.93,  val loss 1.537211, percent error 37.40
# Epoch    18, train loss 0.136692, train error 4.47,  val loss 1.570417, percent error 38.40
# Epoch    19, train loss 0.213740, train error 7.35,  val loss 1.815116, percent error 39.40
# Epoch    20, train loss 0.051310, train error 0.90,  val loss 1.522649, percent error 36.90
# Epoch    21, train loss 0.017750, train error 0.03,  val loss 1.530347, percent error 36.90
# Epoch    22, train loss 0.011816, train error 0.00,  val loss 1.558617, percent error 36.10
# Epoch    23, train loss 0.009226, train error 0.00,  val loss 1.605429, percent error 36.30
# Epoch    24, train loss 0.007928, train error 0.00,  val loss 1.629202, percent error 36.00
# Epoch    25, train loss 0.006917, train error 0.00,  val loss 1.658732, percent error 36.10
# Epoch    26, train loss 0.006277, train error 0.00,  val loss 1.679852, percent error 35.90
# Epoch    27, train loss 0.005651, train error 0.00,  val loss 1.695812, percent error 36.00
# Epoch    28, train loss 0.005174, train error 0.00,  val loss 1.718097, percent error 35.70
# Epoch    29, train loss 0.004788, train error 0.00,  val loss 1.731148, percent error 36.00
# Epoch    30, train loss 0.004458, train error 0.00,  val loss 1.747456, percent error 35.90
# Epoch    31, train loss 0.004164, train error 0.00,  val loss 1.761154, percent error 36.10
# Epoch    32, train loss 0.003925, train error 0.00,  val loss 1.773487, percent error 35.50
# Epoch    33, train loss 0.003704, train error 0.00,  val loss 1.785475, percent error 35.70
# Epoch    34, train loss 0.003505, train error 0.00,  val loss 1.800094, percent error 36.00
# Epoch    35, train loss 0.003325, train error 0.00,  val loss 1.808217, percent error 35.40
# Epoch    36, train loss 0.003170, train error 0.00,  val loss 1.820455, percent error 35.40
# Epoch    37, train loss 0.003025, train error 0.00,  val loss 1.832445, percent error 35.30
# Epoch    38, train loss 0.002898, train error 0.00,  val loss 1.838789, percent error 35.40
# Epoch    39, train loss 0.002775, train error 0.00,  val loss 1.846765, percent error 35.20
# Epoch    40, train loss 0.002717, train error 0.00,  val loss 1.852608, percent error 35.20
# Epoch    41, train loss 0.002663, train error 0.00,  val loss 1.857683, percent error 35.40
# Epoch    42, train loss 0.002612, train error 0.00,  val loss 1.861701, percent error 35.40
# Epoch    43, train loss 0.002563, train error 0.00,  val loss 1.865134, percent error 35.20
# Epoch    44, train loss 0.002516, train error 0.00,  val loss 1.869832, percent error 35.30
# Epoch    45, train loss 0.002470, train error 0.00,  val loss 1.873714, percent error 35.50
# Epoch    46, train loss 0.002428, train error 0.00,  val loss 1.877495, percent error 35.20
# Epoch    47, train loss 0.002385, train error 0.00,  val loss 1.881770, percent error 35.50
# Epoch    48, train loss 0.002344, train error 0.00,  val loss 1.884863, percent error 35.20
# Epoch    49, train loss 0.002305, train error 0.00,  val loss 1.889456, percent error 35.30
# Epoch    50, train loss 0.002267, train error 0.00,  val loss 1.892730, percent error 35.40
# Epoch    51, train loss 0.002229, train error 0.00,  val loss 1.896361, percent error 35.10
# Epoch    52, train loss 0.002193, train error 0.00,  val loss 1.900595, percent error 35.20
# Epoch    53, train loss 0.002160, train error 0.00,  val loss 1.903928, percent error 35.20
# Epoch    54, train loss 0.002126, train error 0.00,  val loss 1.907585, percent error 35.20
# Epoch    55, train loss 0.002093, train error 0.00,  val loss 1.910585, percent error 35.10
# Epoch    56, train loss 0.002062, train error 0.00,  val loss 1.914436, percent error 35.20
# Epoch    57, train loss 0.002031, train error 0.00,  val loss 1.917635, percent error 35.20
# Epoch    58, train loss 0.002002, train error 0.00,  val loss 1.920071, percent error 35.00
# Epoch    59, train loss 0.001973, train error 0.00,  val loss 1.923720, percent error 35.30
# Epoch    60, train loss 0.001958, train error 0.00,  val loss 1.925373, percent error 35.20
# Epoch    61, train loss 0.001944, train error 0.00,  val loss 1.927175, percent error 35.10
# Epoch    62, train loss 0.001930, train error 0.00,  val loss 1.928583, percent error 35.10
# Epoch    63, train loss 0.001917, train error 0.00,  val loss 1.930707, percent error 35.10
# Epoch    64, train loss 0.001904, train error 0.00,  val loss 1.932267, percent error 35.10
# Epoch    65, train loss 0.001890, train error 0.00,  val loss 1.933560, percent error 35.10
# Epoch    66, train loss 0.001877, train error 0.00,  val loss 1.934922, percent error 35.10
# Epoch    67, train loss 0.001865, train error 0.00,  val loss 1.936746, percent error 35.10
# Epoch    68, train loss 0.001852, train error 0.00,  val loss 1.938463, percent error 35.10
# Epoch    69, train loss 0.001839, train error 0.00,  val loss 1.939528, percent error 35.10
# Epoch    70, train loss 0.001827, train error 0.00,  val loss 1.941652, percent error 35.10
# Epoch    71, train loss 0.001815, train error 0.00,  val loss 1.942907, percent error 35.10
# Epoch    72, train loss 0.001803, train error 0.00,  val loss 1.944325, percent error 35.10
# Epoch    73, train loss 0.001792, train error 0.00,  val loss 1.945956, percent error 35.00
# Epoch    74, train loss 0.001780, train error 0.00,  val loss 1.947655, percent error 35.10
# Epoch    75, train loss 0.001768, train error 0.00,  val loss 1.948843, percent error 35.10
# Epoch    76, train loss 0.001757, train error 0.00,  val loss 1.950565, percent error 35.10
# Epoch    77, train loss 0.001746, train error 0.00,  val loss 1.952080, percent error 35.00
# Epoch    78, train loss 0.001735, train error 0.00,  val loss 1.953273, percent error 35.10
# Epoch    79, train loss 0.001724, train error 0.00,  val loss 1.954856, percent error 35.10
# Epoch    80, train loss 0.001718, train error 0.00,  val loss 1.955685, percent error 35.10
# Epoch    81, train loss 0.001713, train error 0.00,  val loss 1.956412, percent error 35.10
# Epoch    82, train loss 0.001707, train error 0.00,  val loss 1.957176, percent error 35.10
# Epoch    83, train loss 0.001702, train error 0.00,  val loss 1.957785, percent error 35.10
# Epoch    84, train loss 0.001697, train error 0.00,  val loss 1.958815, percent error 35.10
# Epoch    85, train loss 0.001692, train error 0.00,  val loss 1.959327, percent error 35.10
# Epoch    86, train loss 0.001686, train error 0.00,  val loss 1.960100, percent error 35.10
# Epoch    87, train loss 0.001681, train error 0.00,  val loss 1.960898, percent error 35.10
# Epoch    88, train loss 0.001676, train error 0.00,  val loss 1.961548, percent error 35.10
# Epoch    89, train loss 0.001671, train error 0.00,  val loss 1.962180, percent error 35.00
# Epoch    90, train loss 0.001666, train error 0.00,  val loss 1.962984, percent error 35.10
# Epoch    91, train loss 0.001661, train error 0.00,  val loss 1.963624, percent error 35.10
# Epoch    92, train loss 0.001656, train error 0.00,  val loss 1.964502, percent error 35.10
# Epoch    93, train loss 0.001651, train error 0.00,  val loss 1.965287, percent error 35.00
# Epoch    94, train loss 0.001646, train error 0.00,  val loss 1.965791, percent error 35.10
# Epoch    95, train loss 0.001641, train error 0.00,  val loss 1.966682, percent error 35.00
# Epoch    96, train loss 0.001636, train error 0.00,  val loss 1.967229, percent error 35.00
# Epoch    97, train loss 0.001631, train error 0.00,  val loss 1.968012, percent error 34.90
# Epoch    98, train loss 0.001626, train error 0.00,  val loss 1.968707, percent error 35.10
# Epoch    99, train loss 0.001621, train error 0.00,  val loss 1.969659, percent error 35.10

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?
